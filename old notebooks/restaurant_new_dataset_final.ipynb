# %%
# !pip install -U textblob

# %%
# For EDA now, will add more libraries as we progress
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
from textblob import TextBlob

# Set nice style for plots
sns.set_theme(style='darkgrid')
sns.dark_palette("#69d", reverse=True, as_cmap=True)
sns.set_context("paper")

# %% [markdown]
# # 1. Read Data
#
# Our data was taken from this database of [Google Local Data 2021](https://datarepo.eng.ucsd.edu/mcauley_group/gdrive/googlelocal/#subsets). We previously used a smaller dataset of Google Restaurant reviews available [here](https://www.kaggle.com/datasets/denizbilginn/google-maps-restaurant-reviews), with only 1100 reviews, but as per our TF's recommendation, we will be using this larger dataset with over 10m reviews for Massachusetts alone. To speed up our EDA, we will be using a sample of 100,000 reviews.
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# Our main dataset, stored in the `df` variable, contains 100,000 reviews. Our columns of interest are `rating`, which is the rating given by the user, `text`, which is the review text, and `gmap_id`, which is the Google Maps ID of the business.
#
# We also have a metadata dataset, stored in the `df_meta` variable, which contains information about each business in Massachusetts. The columns of interest are `gmap_id`, allowing us to join this dataset with the main one, `name`, which is the name of the business, and `description`, which is a brief description of the business. There is also a variable `category` that organizes the businesses into sectors such as non-profits, gyms, restaurants, etc.

# %%
# Load the data
with open('data/review-Massachusetts.json', 'r') as f:
    data = f.readlines()

# Convert to dataframe
data_json_str = "[" + ','.join(data) + "]"
df = pd.read_json(StringIO(data_json_str))

# %%
# Examine df
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5624944 entries, 0 to 5624943
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   pics     object
#  6   resp     object
#  7   gmap_id  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 343.3+ MB
# None
#         user_id              name           time  rating  \
# 0  1.180340e+20     Donna Carlson  1619732714443       5
# 1  1.101673e+20   michael simmons  1615400031636       5
# 2  1.122136e+20       Paul Murray  1593992657241       5
# 3  1.081745e+20  Elba De Oliveira  1582074606394       5
# 4  1.089901e+20      Sherri Mayne  1572962045881       5
#
#                                                 text  pics  resp  \
# 0        People run it make sure you are comfortable  None  None
# 1                      When you need a helping hand.  None  None
# 2  Very Helpful and understanding people definite...  None  None
# 3  Very good place nice things but on Saturday th...  None  None
# 4                                      Awesome place  None  None
#
#                                  gmap_id
# 0  0x89e4a103dd188585:0xfadc47938337579f
# 1  0x89e4a103dd188585:0xfadc47938337579f
# 2  0x89e4a103dd188585:0xfadc47938337579f
# 3  0x89e4a103dd188585:0xfadc47938337579f
# 4  0x89e4a103dd188585:0xfadc47938337579f

# %%
# Also load the whole meta-Massachusetts.json file. This contains metadata about the businesses, 
# since the reviews only contain the business id.
with open('data/meta-Massachusetts.json', 'r') as f:
    data_meta = f.readlines()

data_meta_str = "[" + ','.join(data_meta) + "]"
df_meta = pd.read_json(StringIO(data_meta_str))

# Filter dataframe so that it only contains restaurants
df_meta = df_meta[df_meta['category'].apply(lambda x: isinstance(x, list) and any('restaurant' in category.lower() for category in x) if x is not None else False)]

# %%
# Examine df
print(df_meta.info())
print(df_meta.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16079 entries, 14 to 92514
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              16079 non-null  object
#  1   address           16055 non-null  object
#  2   gmap_id           16079 non-null  object
#  3   description       9341 non-null   object
#  4   latitude          16079 non-null  float64
#  5   longitude         16079 non-null  float64
#  6   category          16079 non-null  object
#  7   avg_rating        16079 non-null  float64
#  8   num_of_reviews    16079 non-null  int64
#  9   price             11987 non-null  object
#  10  hours             15127 non-null  object
#  11  MISC              15994 non-null  object
#  12  state             11728 non-null  object
#  13  relative_results  15090 non-null  object
#  14  url               16079 non-null  object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 2.0+ MB
# None
#                                   name  \
# 14                    Three Star Pizza
# 34                    La Sanghita Cafe
# 114  Spring Restaurant Inc (Xuân Quán)
# 126                        Garden Cafe
# 169           Good Taste Asian Cuisine
#
#                                                address  \
# 14   Three Star Pizza, 409 Cabot St #1, Beverly, MA...
# 34   La Sanghita Cafe, 389 Maverick St, Boston, MA ...
# 114  Spring Restaurant Inc (Xuân Quán), 7 Ayers Vil...
# 126         Garden Cafe, 1 Broadway, Everett, MA 02149
# 169  Good Taste Asian Cuisine, 42 Central St, Ipswi...
#
#                                    gmap_id description   latitude  longitude  \
# 14   0x89e3169821e62d4d:0x14ff0683c1ebca0e        None  42.559072 -70.881542
# 34   0x89e3706a62ba248f:0xdd2878d145d53400        None  42.365695 -71.029044
# 114  0x89e3019449b8fc49:0x4c97b2721aa0b5ee        None  42.791565 -71.183794
# 126  0x89e371b2233c7e03:0x6ef59c94152dc770        None  42.394220 -71.071428
# 169  0x89e318c6e45de21f:0xb3073257db94786c        None  42.680840 -70.839105
#
#                                               category  avg_rating  \
# 14   [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 34                                        [Restaurant]         4.8
# 114  [Vietnamese restaurant, Asian fusion restauran...         4.9
# 126                              [American restaurant]         4.0
# 169             [Asian restaurant, Chinese restaurant]         4.1
#
#      num_of_reviews price                                              hours  \
# 14               48    $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 34               14  None                                               None
# 114              38  None  [[Wednesday, 11AM–8:30PM], [Thursday, 11AM–8:3...
# 126              18  None  [[Wednesday, 7AM–2PM], [Thursday, 7AM–2PM], [F...
# 169              68  None  [[Wednesday, 11AM–10PM], [Thursday, 11AM–10PM]...
#
#                                                   MISC  \
# 14   {'Service options': ['Takeout', 'Delivery'], '...
# 34   {'Service options': ['Delivery'], 'Highlights'...
# 114  {'Service options': ['No-contact delivery', 'D...
# 126  {'Service options': ['Takeout', 'Dine-in', 'De...
# 169  {'Service options': ['Delivery', 'Takeout'], '...
#
#                                      state  \
# 14                      Permanently closed
# 34                                    None
# 114  Closes soon ⋅ 8:30PM ⋅ Opens 11AM Thu
# 126                 Closed ⋅ Opens 7AM Thu
# 169                     Open ⋅ Closes 10PM
#
#                                       relative_results  \
# 14   [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 34   [0x89e371cb53850b7f:0x7e6646ef9ede69d8, 0x89e3...
# 114                                               None
# 126  [0x89e371fc3b8d9d0d:0x7fdbb6fe2876f623, 0x89e3...
# 169  [0x89e318c1482e95bd:0x812921e26a6dc253, 0x89e3...
#
#                                                    url
# 14   https://www.google.com/maps/place//data=!4m2!3...
# 34   https://www.google.com/maps/place//data=!4m2!3...
# 114  https://www.google.com/maps/place//data=!4m2!3...
# 126  https://www.google.com/maps/place//data=!4m2!3...
# 169  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Merging the dataframes on 'gmap_id'
# 'inner' will only include rows that have matching 'gmap_id' in both dataframes
df_combined = pd.merge(df, df_meta, on='gmap_id', how='inner')

# %%
# Examine the combined dataframe
print(df_combined.info())
print(df_combined.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2552669 entries, 0 to 2552668
# Data columns (total 22 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   user_id           float64
#  1   name_x            object
#  2   time              int64
#  3   rating            int64
#  4   text              object
#  5   pics              object
#  6   resp              object
#  7   gmap_id           object
#  8   name_y            object
#  9   address           object
#  10  description       object
#  11  latitude          float64
#  12  longitude         float64
#  13  category          object
#  14  avg_rating        float64
#  15  num_of_reviews    int64
#  16  price             object
#  17  hours             object
#  18  MISC              object
#  19  state             object
#  20  relative_results  object
#  21  url               object
# dtypes: float64(4), int64(3), object(15)
# memory usage: 428.5+ MB
# None
#         user_id             name_x           time  rating  \
# 0  1.053246e+20            Jessica  1515819902193       4
# 1  1.053246e+20            Jessica  1515819902193       4
# 2  1.085975e+20  Joey Taraborrelli  1529934471266       5
# 3  1.085975e+20  Joey Taraborrelli  1529934471266       5
# 4  1.118395e+20    Joseph Cannella  1499695432617       5
#
#                                                 text  \
# 0  What a great experience. I tried the chicken t...
# 1  What a great experience. I tried the chicken t...
# 2  The owner, T, is a wonderful man. Super friend...
# 3  The owner, T, is a wonderful man. Super friend...
# 4  Love this place,  always have & always will.  ...
#
#                                                 pics  resp  \
# 0  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 1  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 2                                               None  None
# 3                                               None  None
# 4                                               None  None
#
#                                  gmap_id            name_y  \
# 0  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 1  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 2  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 3  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 4  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
#
#                                              address  ...  longitude  \
# 0  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
# 1  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
# 2  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
# 3  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
# 4  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
#
#                                             category  avg_rating  \
# 0  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 1  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 2  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 3  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 4  [Pizza restaurant, Italian restaurant, Deliver...         3.9
#
#   num_of_reviews  price                                              hours  \
# 0             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 1             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 2             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 3             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 4             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
#
#                                                 MISC               state  \
# 0  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 1  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 2  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 3  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 4  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
#
#                                     relative_results  \
# 0  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 1  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 2  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 3  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 4  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...
#
# [5 rows x 22 columns]

# %% [markdown]
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# We merged the main dataset and our meta dataset based on `gmap_id` and filtered out the ones of restaurants.
#
# We will clean up the dataframe for our purpose. From below we see that we can probably get rid of these columns: `name_x` (since we don't care about the name of the reviewer, having `user_id` is enough to identify them; `time` (for now we don't care about when the reviewers wrote the reviews); `pics` (we don't care about pictures first, but might use it in the future if time permits); `resp` (most of them are `None`); `gmap_id`(we can identify restaurants based on their names which is easier to understand); `description` (most of them are `None`); `relative_results`; `url`)
#
# We see that there are duplicates in our merged dataset. We will drop the duplicates after we clean up the dataframe to only keep necessary columns.

# %%
df_combined.head()
# Out:
#         user_id             name_x           time  rating  \
# 0  1.053246e+20            Jessica  1515819902193       4
# 1  1.053246e+20            Jessica  1515819902193       4
# 2  1.085975e+20  Joey Taraborrelli  1529934471266       5
# 3  1.085975e+20  Joey Taraborrelli  1529934471266       5
# 4  1.118395e+20    Joseph Cannella  1499695432617       5
#
#                                                 text  \
# 0  What a great experience. I tried the chicken t...
# 1  What a great experience. I tried the chicken t...
# 2  The owner, T, is a wonderful man. Super friend...
# 3  The owner, T, is a wonderful man. Super friend...
# 4  Love this place,  always have & always will.  ...
#
#                                                 pics  resp  \
# 0  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 1  [{'url': ['https://lh5.googleusercontent.com/p...  None
# 2                                               None  None
# 3                                               None  None
# 4                                               None  None
#
#                                  gmap_id            name_y  \
# 0  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 1  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 2  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 3  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 4  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
#
#                                              address  ...  longitude  \
# 0  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
# 1  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
# 2  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
# 3  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
# 4  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  ... -70.881542
#
#                                             category  avg_rating  \
# 0  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 1  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 2  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 3  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 4  [Pizza restaurant, Italian restaurant, Deliver...         3.9
#
#   num_of_reviews  price                                              hours  \
# 0             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 1             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 2             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 3             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 4             48     $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
#
#                                                 MISC               state  \
# 0  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 1  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 2  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 3  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 4  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
#
#                                     relative_results  \
# 0  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 1  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 2  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 3  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
# 4  [0x89e31418f27b6a29:0x2fd2e82a6f96214c, 0x89e3...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...
#
# [5 rows x 22 columns]

# %%
df_cleaned
# Out:
#               user_id  rating  \
# 0        1.053246e+20       4
# 1        1.053246e+20       4
# 2        1.085975e+20       5
# 3        1.085975e+20       5
# 4        1.118395e+20       5
# ...               ...     ...
# 2552664  1.035690e+20       5
# 2552665  1.022961e+20       5
# 2552666  1.026475e+20       5
# 2552667  1.099938e+20       5
# 2552668  1.042116e+20       5
#
#                                                       text  \
# 0        What a great experience. I tried the chicken t...
# 1        What a great experience. I tried the chicken t...
# 2        The owner, T, is a wonderful man. Super friend...
# 3        The owner, T, is a wonderful man. Super friend...
# 4        Love this place,  always have & always will.  ...
# ...                                                    ...
# 2552664                                               None
# 2552665                                               None
# 2552666                                               None
# 2552667                                               None
# 2552668                                               None
#
#                                     name_y  \
# 0                         Three Star Pizza
# 1                         Three Star Pizza
# 2                         Three Star Pizza
# 3                         Three Star Pizza
# 4                         Three Star Pizza
# ...                                    ...
# 2552664  Martha's Vineyard Chowder Company
# 2552665  Martha's Vineyard Chowder Company
# 2552666  Martha's Vineyard Chowder Company
# 2552667  Martha's Vineyard Chowder Company
# 2552668  Martha's Vineyard Chowder Company
#
#                                                    address   latitude  \
# 0        Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072
# 1        Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072
# 2        Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072
# 3        Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072
# 4        Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072
# ...                                                    ...        ...
# 2552664  Martha's Vineyard Chowder Company, 9 Oak Bluff...  41.457841
# 2552665  Martha's Vineyard Chowder Company, 9 Oak Bluff...  41.457841
# 2552666  Martha's Vineyard Chowder Company, 9 Oak Bluff...  41.457841
# 2552667  Martha's Vineyard Chowder Company, 9 Oak Bluff...  41.457841
# 2552668  Martha's Vineyard Chowder Company, 9 Oak Bluff...  41.457841
#
#          longitude                                           category  \
# 0       -70.881542  [Pizza restaurant, Italian restaurant, Deliver...
# 1       -70.881542  [Pizza restaurant, Italian restaurant, Deliver...
# 2       -70.881542  [Pizza restaurant, Italian restaurant, Deliver...
# 3       -70.881542  [Pizza restaurant, Italian restaurant, Deliver...
# 4       -70.881542  [Pizza restaurant, Italian restaurant, Deliver...
# ...            ...                                                ...
# 2552664 -70.557289  [Seafood restaurant, American restaurant, Rest...
# 2552665 -70.557289  [Seafood restaurant, American restaurant, Rest...
# 2552666 -70.557289  [Seafood restaurant, American restaurant, Rest...
# 2552667 -70.557289  [Seafood restaurant, American restaurant, Rest...
# 2552668 -70.557289  [Seafood restaurant, American restaurant, Rest...
#
#          avg_rating  num_of_reviews price  \
# 0               3.9              48    $$
# 1               3.9              48    $$
# 2               3.9              48    $$
# 3               3.9              48    $$
# 4               3.9              48    $$
# ...             ...             ...   ...
# 2552664         4.4             445    $$
# 2552665         4.4             445    $$
# 2552666         4.4             445    $$
# 2552667         4.4             445    $$
# 2552668         4.4             445    $$
#
#                                                      hours  \
# 0        [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 1        [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 2        [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 3        [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 4        [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# ...                                                    ...
# 2552664  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 2552665  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 2552666  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 2552667  [[Thursday, Closed], [Friday, Closed], [Saturd...
# 2552668  [[Thursday, Closed], [Friday, Closed], [Saturd...
#
#                                                       MISC               state
# 0        {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 1        {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 2        {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 3        {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 4        {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# ...                                                    ...                 ...
# 2552664  {'Service options': ['Outdoor seating', 'Curbs...                 NaN
# 2552665  {'Service options': ['Outdoor seating', 'Curbs...                 NaN
# 2552666  {'Service options': ['Outdoor seating', 'Curbs...                 NaN
# 2552667  {'Service options': ['Outdoor seating', 'Curbs...                 NaN
# 2552668  {'Service options': ['Outdoor seating', 'Curbs...                 NaN
#
# [2552669 rows x 14 columns]

# %%
columns_to_drop = ['name_x', 'time', 'pics', 'resp', 'description', 'relative_results', 'url']
df_cleaned = df_combined.drop(columns=columns_to_drop)

# Drop duplicates based on `user_id` and `gmap_id` to ensure unique reviews per user per restaurant
df_cleaned = df_cleaned.drop_duplicates(subset=['user_id', 'gmap_id'])

df_cleaned.head()
# Out:
#         user_id  rating                                               text  \
# 0  1.053246e+20       4  What a great experience. I tried the chicken t...
# 2  1.085975e+20       5  The owner, T, is a wonderful man. Super friend...
# 4  1.118395e+20       5  Love this place,  always have & always will.  ...
# 6  1.149863e+20       5  Awesome pizzas and subs. Their hawaiin pizza i...
# 8  1.012653e+20       1  This was the worst experience ever,  they told...
#
#                                  gmap_id            name_y  \
# 0  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 2  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 4  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 6  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 8  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
#
#                                              address   latitude  longitude  \
# 0  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
# 2  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
# 4  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
# 6  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
# 8  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
#
#                                             category  avg_rating  \
# 0  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 2  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 4  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 6  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 8  [Pizza restaurant, Italian restaurant, Deliver...         3.9
#
#    num_of_reviews price                                              hours  \
# 0              48    $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 2              48    $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 4              48    $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 6              48    $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
# 8              48    $$  [[Thursday, 11AM–8PM], [Friday, 11AM–10PM], [S...
#
#                                                 MISC               state
# 0  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 2  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 4  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 6  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed
# 8  {'Service options': ['Takeout', 'Delivery'], '...  Permanently closed

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2524427 entries, 0 to 2552668
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   user_id         float64
#  1   rating          int64
#  2   text            object
#  3   gmap_id         object
#  4   name_y          object
#  5   address         object
#  6   latitude        float64
#  7   longitude       float64
#  8   category        object
#  9   avg_rating      float64
#  10  num_of_reviews  int64
#  11  price           object
#  12  hours           object
#  13  MISC            object
#  14  state           object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 308.2+ MB

# %% [markdown]
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# The `MISC` column contains dictionaries with useful information. We decided to further process this column and extract the attributes out as new columns of our dataframe.

# %%
print(df_cleaned.loc[0, 'MISC'])
# Out:
# {'Service options': ['Takeout', 'Delivery'], 'Accessibility': ['Wheelchair accessible entrance'], 'Offerings': ['Comfort food', 'Late-night food', 'Vegetarian options'], 'Dining options': ['Lunch', 'Dinner', 'Dessert'], 'Payments': ['Debit cards']}

# %%
# First, ensure all entries in 'MISC' are dictionaries; replace None with empty dictionaries
df_cleaned['MISC'] = df_cleaned['MISC'].apply(lambda x: x if isinstance(x, dict) else {})

# Convert the 'MISC' column to a DataFrame where each key in the dictionary becomes a column
misc_expanded = pd.DataFrame(df_cleaned['MISC'].tolist())

# %%
# Join the expanded 'MISC' DataFrame with the original 'df_cleaned', excluding the 'MISC' column
df_expanded = pd.concat([df_cleaned.drop(columns=['MISC']), misc_expanded], axis=1)

# %%
df_expanded.head()
# Out:
#         user_id  rating                                               text  \
# 0  1.053246e+20     4.0  What a great experience. I tried the chicken t...
# 2  1.085975e+20     5.0  The owner, T, is a wonderful man. Super friend...
# 4  1.118395e+20     5.0  Love this place,  always have & always will.  ...
# 6  1.149863e+20     5.0  Awesome pizzas and subs. Their hawaiin pizza i...
# 8  1.012653e+20     1.0  This was the worst experience ever,  they told...
#
#                                  gmap_id            name_y  \
# 0  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 2  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 4  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 6  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
# 8  0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza
#
#                                              address   latitude  longitude  \
# 0  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
# 2  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
# 4  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
# 6  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
# 8  Three Star Pizza, 409 Cabot St #1, Beverly, MA...  42.559072 -70.881542
#
#                                             category  avg_rating  ...  \
# 0  [Pizza restaurant, Italian restaurant, Deliver...         3.9  ...
# 2  [Pizza restaurant, Italian restaurant, Deliver...         3.9  ...
# 4  [Pizza restaurant, Italian restaurant, Deliver...         3.9  ...
# 6  [Pizza restaurant, Italian restaurant, Deliver...         3.9  ...
# 8  [Pizza restaurant, Italian restaurant, Deliver...         3.9  ...
#
#         Payments Highlights Popular for Amenities Atmosphere Health & safety  \
# 0  [Debit cards]        NaN         NaN       NaN        NaN             NaN
# 2  [Debit cards]        NaN         NaN       NaN        NaN             NaN
# 4  [Debit cards]        NaN         NaN       NaN        NaN             NaN
# 6  [Debit cards]        NaN         NaN       NaN        NaN             NaN
# 8  [Debit cards]        NaN         NaN       NaN        NaN             NaN
#
#   Crowd Planning From the business Health and safety
# 0   NaN      NaN               NaN               NaN
# 2   NaN      NaN               NaN               NaN
# 4   NaN      NaN               NaN               NaN
# 6   NaN      NaN               NaN               NaN
# 8   NaN      NaN               NaN               NaN
#
# [5 rows x 28 columns]

# %%
df_expanded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2552669 entries, 0 to 2328123
# Data columns (total 28 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   user_id            float64
#  1   rating             float64
#  2   text               object
#  3   gmap_id            object
#  4   name_y             object
#  5   address            object
#  6   latitude           float64
#  7   longitude          float64
#  8   category           object
#  9   avg_rating         float64
#  10  num_of_reviews     float64
#  11  price              object
#  12  hours              object
#  13  state              object
#  14  Service options    object
#  15  Accessibility      object
#  16  Offerings          object
#  17  Dining options     object
#  18  Payments           object
#  19  Highlights         object
#  20  Popular for        object
#  21  Amenities          object
#  22  Atmosphere         object
#  23  Health & safety    object
#  24  Crowd              object
#  25  Planning           object
#  26  From the business  object
#  27  Health and safety  object
# dtypes: float64(6), object(22)
# memory usage: 564.8+ MB

# %%
columns_of_interest = [
    "Service options", "Accessibility", "Offerings", "Dining options",
    "Payments", "Highlights", "Popular for", "Amenities",
    "Atmosphere", "Health & safety", "Crowd", "Planning",
    "From the business", "Health and safety"
]

# Initialize a dictionary to hold the unique values for each column
unique_values = {}

# Iterate over each column of interest
for column in columns_of_interest:
    # Extract the column's data
    column_data = df_expanded[column]
    
    # Since the data might contain lists, we need to flatten these into a single list before finding unique values
    # We'll use a set to automatically keep only unique items
    flattened_set = set()
    for item in column_data.dropna():  # Drop NA values to avoid errors
        if isinstance(item, list):  # Check if the item is a list
            flattened_set.update(item)  # Add all items in the list to the set
        else:
            flattened_set.add(item)  # Add the item itself if it's not a list
    
    # Store the unique values for this column in our dictionary
    unique_values[column] = list(flattened_set)  # Convert the set back to a list for readability

# Or, to print the unique values for all columns of interest:
for column, values in unique_values.items():
    print(f"{column}: {values}\n")
# Out:
# Service options: ['Curbside pickup', 'In-store pick-up', 'Same-day delivery', 'Takeaway', 'Dine-in', 'Drive-through', 'Outdoor seating', 'In-store pickup', 'Online appointments', 'Takeout', 'In-store shopping', 'Delivery', 'No-contact delivery']
#
# Accessibility: ['Wheelchair accessible parking lot', 'Wheelchair accessible seating', 'Wheelchair-accessible car park', 'Wheelchair accessible restroom', 'Assisted listening devices', 'Wheelchair accessible elevator', 'Wheelchair-accessible entrance', 'Wheelchair-accessible seating', 'Wheelchair rental', 'Wheelchair-accessible toilet', 'Wheelchair-accessible lift', 'Wheelchair accessible entrance']
#
# Offerings: ['Spirits', 'Happy hour drinks', 'Ethanol-free gas', 'Salad bar', 'Food at bar', 'Car wash', 'Happy-hour food', 'Late-night food', 'Comfort food', 'Vegetarian options', 'Organic products', 'Happy-hour drinks', 'Service guarantee', 'Cocktails', 'All you can eat', 'Small plates', 'Organic dishes', 'Hard liquor', 'Prepared foods', 'Healthy options', 'Beer', 'Halal food', 'Happy hour food', 'Braille menu', 'Dancing', 'Coffee', 'Full service gas', 'Food', "Kids' menu", 'Quick bite', 'Wine', 'Alcohol']
#
# Dining options: ['Lunch', 'Dinner', 'Dessert', 'Counter service', 'Pay ahead', 'Breakfast', 'Catering', 'Outside food allowed', 'Seating']
#
# Payments: ['Cash only', 'Cheques', 'Cash-only', 'Checks', 'Debit cards', 'NFC mobile payments', 'Credit cards']
#
# Highlights: ['LGBTQ friendly', 'Karaoke', 'Sport', 'Great dessert', 'Cabaret', 'Rooftop seating', 'Bar games', 'Great cocktails', 'Great wine list', 'Great coffee', 'Serves local specialty', 'Active military discounts', 'Great tea selection', 'Transgender safe space', 'Trivia night', 'Sports', '3D movies', 'Great beer selection', 'Fireplace', 'Transgender safespace', 'LGBTQ-friendly', 'Great bar food', 'Play area', 'Live music', 'Great produce', 'Live performances', 'Fast service']
#
# Popular for: ['Lunch', 'Dinner', 'Breakfast', 'Solo dining', 'Good for working on laptop']
#
# Amenities: ['Bar on site', 'High chairs', 'Gender-neutral restroom', 'Gender-neutral toilets', 'Wi-Fi', 'Restaurant', 'Restroom', 'Stadium seating', 'Public restroom', 'Toilets', 'Good for kids', 'Bar onsite']
#
# Atmosphere: ['Quiet', 'Upmarket', 'Upscale', 'Historic', 'Cosy', 'Trending', 'Casual', 'Cozy', 'Romantic']
#
# Health & safety: ['Safety dividers at checkout', 'Temperature check required', 'Staff required to disinfect surfaces between visits', 'Staff get temperature checks', 'Staff wear masks', 'Mask required', 'Reservations required']
#
# Crowd: ['Groups', 'Locals', 'Tourists', 'College students', 'Family-friendly', 'Family friendly', 'University students']
#
# Planning: ['Accepts reservations', 'Quick visit', 'LGBTQ friendly', 'Lunch reservations recommended', 'Transgender safespace', 'Dinner reservations recommended', 'Usually a wait', 'Appointments recommended', 'Membership required']
#
# From the business: ['Identifies as veteran-led', 'Identifies as women-led', 'Identifies as Black-owned']
#
# Health and safety: ['Safety dividers at checkout', 'Temperature check required', 'Staff required to disinfect surfaces between visits', 'Staff get temperature checks', 'Staff wear masks', 'Mask required', 'Reservations required']

# %%
# Counting NaN values in each column of df_expanded
nan_counts = df_expanded.isna().sum()

# Displaying the count of NaN values per column
print(nan_counts)
# Out:
# user_id                28242
# rating                 28242
# text                 1220681
# gmap_id                28242
# name_y                 28242
# address                28899
# latitude               28242
# longitude              28242
# category               28242
# avg_rating             28242
# num_of_reviews         28242
# price                 239227
# hours                  90075
# state                1165444
# Service options        89331
# Accessibility         223478
# Offerings             211734
# Dining options        401109
# Payments              950551
# Highlights            789779
# Popular for           423542
# Amenities             256395
# Atmosphere            373552
# Health & safety      1030766
# Crowd                 388729
# Planning             1349060
# From the business    2452245
# Health and safety    2514255
# dtype: int64

# %% [markdown]
# <div style="background-color:#3F7FBF; color:white; padding:10px">
# Since we will focus on reviews, we decided to drop rows with `text` (which is the review column) empty. We will also drop the rows with `rating` empty.

# %%
# Drop rows where the 'text' column is NaN
df_expanded_clean = df_expanded.dropna(subset=['text', 'rating'])
df_expanded_clean.isna().sum()
# Out:
# user_id                    0
# rating                     0
# text                       0
# gmap_id                    0
# name_y                     0
# address                  375
# latitude                   0
# longitude                  0
# category                   0
# avg_rating                 0
# num_of_reviews             0
# price                 118502
# hours                  32504
# state                 589361
# Service options        46659
# Accessibility         117034
# Offerings             111042
# Dining options        208545
# Payments              496633
# Highlights            414100
# Popular for           220375
# Amenities             134411
# Atmosphere            195120
# Health & safety       539678
# Crowd                 204638
# Planning              707240
# From the business    1279778
# Health and safety    1311619
# dtype: int64

# %% [markdown]
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# Let's further inspect these columns and decide either to drop them or process them.
#
# `Planning`, `From the business`, and `Health and safety` simply just have too many missing values, so we will drop them.
#
# We decided to drop `address` column since we will be able to infer the address based on names of the restaurants and the latitude and longitude.
#
# `state` describes the current states of the restraurants when the dataset authors scraped it. This is not that helpful for our analysis so we will drop this column too.
#
# There are some other variables which are not important for our analysis for now. We will drop them as well and start thinking about how to process the rest (e.g. one-hot encode).

# %%
df_expanded_clean['state'].unique()
# Out:
# array(['Permanently closed', None,
#        'Closes soon ⋅ 8:30PM ⋅ Opens 11AM Thu', 'Open ⋅ Closes 10PM',
#        'Closes soon ⋅ 4PM ⋅ Opens 8AM Thu', 'Open ⋅ Closes 8PM',
#        'Open ⋅ Closes 5PM', 'Closed ⋅ Opens 11AM',
#        'Closed ⋅ Opens 11:30AM', 'Closed ⋅ Opens 5PM Thu',
#        'Open ⋅ Closes 2AM', 'Closed ⋅ Opens 11AM Wed',
#        'Closed ⋅ Opens 8AM Wed', 'Closed ⋅ Opens 8:30AM Wed',
#        'Closed ⋅ Opens 7:30AM Wed', 'Closed ⋅ Opens 7:15AM',
#        'Closes soon ⋅ 9PM ⋅ Opens 10AM Tue', 'Open 24 hours',
#        'Closed ⋅ Opens 7AM', 'Closed ⋅ Opens 7:30AM Mon',
#        'Closed ⋅ Opens 5:30AM Mon', 'Closed ⋅ Opens 11AM Mon',
#        'Closed ⋅ Opens 9AM', 'Closed ⋅ Opens 12PM', 'Open ⋅ Closes 9PM',
#        'Open ⋅ Closes 7PM', 'Open ⋅ Closes 4PM', 'Closed ⋅ Opens 10AM',
#        'Open ⋅ Closes 11PM', 'Closed ⋅ Opens 8AM Thu',
#        'Closed ⋅ Opens 10:30AM Thu', 'Open ⋅ Closes 6PM',
#        'Closed ⋅ Opens 11AM Fri', 'Open ⋅ Closes 8:30PM',
#        'Closes soon ⋅ 2PM ⋅ Opens 5:30AM Wed', 'Temporarily closed',
#        'Closed ⋅ Opens 12PM Tue', 'Closed ⋅ Opens 10:30AM Mon',
#        'Closed ⋅ Opens 1PM Sun', 'Closed ⋅ Opens 8AM Mon',
#        'Closed ⋅ Opens 8AM', 'Closes soon ⋅ 8PM ⋅ Opens 11:30AM Thu',
#        'Closed ⋅ Opens 3:30PM', 'Closed ⋅ Opens 7:30AM Tue',
#        'Open ⋅ Closes 3PM', 'Closed ⋅ Opens 7AM Mon',
#        'Open ⋅ Closes 2:30AM', 'Closed ⋅ Opens 8AM Sun',
#        'Closed ⋅ Opens 11AM Sun', 'Closed ⋅ Opens 6AM Sun',
#        'Closed ⋅ Opens 9AM Tue', 'Open ⋅ Closes 12:30AM',
#        'Closes soon ⋅ 8PM ⋅ Opens 8AM Sun', 'Open ⋅ Closes 10:30PM',
#        'Closed ⋅ Opens 4PM', 'Open ⋅ Closes 9:30PM', 'Open ⋅ Closes 2PM',
#        'Closed ⋅ Opens 9AM Thu', 'Closed ⋅ Opens 12PM Thu',
#        'Closed ⋅ Opens 11:30AM Wed', 'Closed ⋅ Opens 11AM Tue',
#        'Closed ⋅ Opens 5AM Tue', 'Closed ⋅ Opens 9:30AM Tue',
#        'Closed ⋅ Opens 2PM', 'Opens soon ⋅ 11:30AM',
#        'Closed ⋅ Opens 10:30AM', 'Closes soon ⋅ 9PM ⋅ Opens 11:30AM Thu',
#        'Closed ⋅ Opens 10AM Thu', 'Open ⋅ Closes 7:30PM',
#        'Closed ⋅ Opens 5PM', 'Closes soon ⋅ 9PM ⋅ Opens 11:30AM Wed',
#        'Open ⋅ Closes 10:15PM', 'Open now', 'Closed ⋅ Opens 5AM Mon',
#        'Closed ⋅ Opens 5PM Mon', 'Closed ⋅ Opens 8:30AM Mon',
#        'Closed ⋅ Opens 4PM Mon', 'Closed ⋅ Opens 9AM Sun',
#        'Closed ⋅ Opens 12AM Mon', 'Closed ⋅ Opens 5AM',
#        'Closed ⋅ Opens 11:30AM Sat', 'Closed ⋅ Opens 6AM',
#        'Closed ⋅ Opens 8:30AM Fri', 'Closed ⋅ Opens 10AM Fri',
#        'Closed ⋅ Opens 5:30AM Fri', 'Closes soon ⋅ 7PM ⋅ Opens 7AM Thu',
#        'Closed ⋅ Opens 6AM Thu', 'Closed ⋅ Opens 11AM Thu',
#        'Closed ⋅ Opens 6AM Wed', 'Closed ⋅ Opens 7AM Wed',
#        'Closed ⋅ Opens 4:30AM Wed', 'Opens soon ⋅ 11AM',
#        'Closed ⋅ Opens 6:30AM Thu', 'Closed ⋅ Opens 7:30AM', 'Closed',
#        'Closes soon ⋅ 9PM ⋅ Opens 11AM Tue', 'Closed ⋅ Opens 4:30PM Tue',
#        'Closed ⋅ Opens 11:30AM Tue', 'Closed ⋅ Opens 4PM Thu',
#        'Closed ⋅ Opens 12PM Wed', 'Opens soon ⋅ 4PM',
#        'Open ⋅ Closes 1:30AM', 'Open ⋅ Closes 12AM',
#        'Closed ⋅ Opens 4PM Tue', 'Closed ⋅ Opens 5PM Tue',
#        'Closed ⋅ Opens 12PM Mon', 'Closed ⋅ Opens 6AM Mon',
#        'Closed ⋅ Opens 7PM Wed', 'Closed ⋅ Opens 9:30AM Wed',
#        'Closed ⋅ Opens 3PM', 'Closed ⋅ Opens 12PM Sun',
#        'Open ⋅ Closes 8PM ⋅ Reopens 10PM', 'Closed ⋅ Opens 7AM Sun',
#        'Open ⋅ Closes 12PM', 'Closed ⋅ Opens 4:30AM',
#        'Closed ⋅ Opens 5:30AM', 'Closed ⋅ Opens 11AM Sat',
#        'Closed ⋅ Opens 9AM Sat', 'Closes soon ⋅ 7:30PM ⋅ Opens 1PM Sat',
#        'Closed ⋅ Opens 8AM Sat', 'Opens soon ⋅ 6:30AM',
#        'Closed ⋅ Opens 5AM Thu', 'Closed ⋅ Opens 5:30AM Thu',
#        'Open ⋅ Closes 4:30PM', 'Closed ⋅ Opens 1PM',
#        'Closed ⋅ Opens 5PM Fri', 'Closed ⋅ Opens 10:30AM Tue',
#        'Closed ⋅ Opens 4:30AM Mon', 'Closes soon ⋅ 10PM ⋅ Opens 10AM Mon',
#        'Open ⋅ Closes 1AM', 'Closed ⋅ Opens 7AM Thu',
#        'Closed ⋅ Opens 9AM Mon', 'Closed ⋅ Opens 9AM Fri',
#        'Closed ⋅ Opens 12PM Fri', 'Closes soon ⋅ 9PM ⋅ Opens 9AM Fri',
#        'Open ⋅ Closes 9:45PM', 'Closed ⋅ Opens 1:30PM',
#        'Closed ⋅ Opens 5PM Wed', 'Opens soon ⋅ 5AM',
#        'Closed ⋅ Opens 11:45AM', 'Opens soon ⋅ 8AM',
#        'Closed ⋅ Opens 12:30PM', 'Closed ⋅ Opens 6:30AM',
#        'Closes soon ⋅ 10PM ⋅ Opens 12PM Sun',
#        'Closes soon ⋅ 9PM ⋅ Opens 10AM Sun', 'Closed ⋅ Opens 10:30AM Sat',
#        'Closed ⋅ Opens 1PM Sat', 'Closes soon ⋅ 11PM ⋅ Opens 11:30AM Sat',
#        'Closed ⋅ Opens 7AM Sat', 'Closed ⋅ Opens 6AM Sat',
#        'Closes soon ⋅ 9PM ⋅ Opens 9AM Sat',
#        'Closes soon ⋅ 7PM ⋅ Opens 11AM Sat',
#        'Closes soon ⋅ 5PM ⋅ Opens 9AM Sat',
#        'Closes soon ⋅ 4PM ⋅ Opens 5AM Sat', 'Closed ⋅ Opens 4:30PM',
#        'Closed ⋅ Opens 5AM Fri', 'Closed ⋅ Opens 4PM Fri',
#        'Closed ⋅ Opens 6AM Fri', 'Opens soon ⋅ 12PM',
#        'Closed ⋅ Opens 3PM Thu', 'Closed ⋅ Opens 9:30AM Thu',
#        'Closes soon ⋅ 10PM ⋅ Opens 10:30AM Thu',
#        'Closes soon ⋅ 7PM ⋅ Opens 5AM Thu', 'Closed ⋅ Opens 11:30AM Thu',
#        'Closed ⋅ Opens 11:15AM', 'Closes soon ⋅ 11PM ⋅ Opens 11AM Tue',
#        'Closed ⋅ Opens 8AM Tue', 'Closes soon ⋅ 8:30PM ⋅ Opens 11AM Tue',
#        'Closed ⋅ Opens 3PM Tue', 'Opens soon ⋅ 5PM',
#        'Closes soon ⋅ 4PM ⋅ Opens 5:30AM Tue', 'Closed ⋅ Opens 7AM Tue',
#        'Closed ⋅ Opens 12AM Tue', 'Closed ⋅ Opens 3PM Wed',
#        'Closed ⋅ Opens 6AM Tue', 'Closed ⋅ Opens 9:30AM',
#        'Closed ⋅ Opens 2:30PM Tue',
#        'Closes soon ⋅ 12AM ⋅ Opens 11:30AM Mon',
#        'Closed ⋅ Opens 11:30AM Mon',
#        'Closes soon ⋅ 12AM ⋅ Opens 10:30AM Mon',
#        'Closes soon ⋅ 8PM ⋅ Opens 4PM Wed', 'Closed ⋅ Opens 10AM Mon',
#        'Closes soon ⋅ 3PM ⋅ Opens 7AM Mon', 'Opens soon ⋅ 6AM',
#        'Open ⋅ Closes 2AM ⋅ Reopens 3PM', 'Closed ⋅ Opens 9:30AM Sun',
#        'Closed ⋅ Opens 5AM Sun', 'Closed ⋅ Opens 10AM Sun',
#        'Closes soon ⋅ 8PM ⋅ Opens 3PM Sun',
#        'Closes soon ⋅ 5PM ⋅ Opens 11AM Mon', 'Open ⋅ Closes 11:30PM',
#        'Closes soon ⋅ 4PM ⋅ Opens 10AM Sun',
#        'Closes soon ⋅ 12AM ⋅ Opens 11AM Sat', 'Closed ⋅ Opens 7:30AM Sat',
#        'Closed ⋅ Opens 5PM Sat', 'Closes soon ⋅ 10PM ⋅ Opens 11AM Sat',
#        'Open ⋅ Closes 10:30AM ⋅ Reopens 11AM', 'Closed ⋅ Opens 10:45AM',
#        'Closed ⋅ Opens 5:30PM', 'Closed ⋅ Opens 7AM Fri',
#        'Closed ⋅ Opens 8AM Fri', 'Open ⋅ Closes 8:45PM',
#        'Open ⋅ Closes 4AM', 'Closed ⋅ Opens 8:30AM Thu',
#        'Closed ⋅ Opens 2PM Thu', 'Closes soon ⋅ 9:30PM ⋅ Opens 12PM Thu',
#        'Closes soon ⋅ 9PM ⋅ Opens 11AM Thu',
#        'Closes soon ⋅ 3PM ⋅ Opens 6AM Thu', 'Open ⋅ Closes 6:30PM',
#        'Open ⋅ Closes 1PM', 'Opens soon ⋅ 7AM', 'Closed ⋅ Opens 5AM Wed',
#        'Closed ⋅ Opens 10AM Wed',
#        'Closes soon ⋅ 10PM ⋅ Opens 11:30AM Wed',
#        'Closes soon ⋅ 9PM ⋅ Opens 5AM Wed',
#        'Closes soon ⋅ 3PM ⋅ Opens 10:30AM Wed', 'Closed ⋅ Opens 4PM Wed',
#        'Open ⋅ Closes 12:30PM ⋅ Reopens 7PM', 'Opens soon ⋅ 2:30PM',
#        'Closed ⋅ Opens 6:30AM Mon', 'Closed ⋅ Opens 6PM',
#        'Closed ⋅ Opens 9:30AM Mon',
#        'Closes soon ⋅ 10PM ⋅ Opens 10:30AM Mon',
#        'Closed ⋅ Opens 10:30AM Sun', 'Closes soon ⋅ 7PM ⋅ Opens 12PM Sun',
#        'Closed ⋅ Opens 7PM', 'Closed ⋅ Opens 8:30AM',
#        'Open ⋅ Closes 4PM ⋅ Reopens 5PM', 'Closed ⋅ Opens 4AM Tue',
#        'Closed ⋅ Opens 12:30PM Wed', 'Closes soon ⋅ 12AM ⋅ Opens 6AM Tue',
#        'Closed ⋅ Opens 8:30AM Tue', 'Closes soon ⋅ 10PM ⋅ Opens 11AM Tue',
#        'Closed ⋅ Opens 3:30PM Tue',
#        'Closes soon ⋅ 9:30PM ⋅ Opens 11:30AM Tue',
#        'Closes soon ⋅ 7PM ⋅ Opens 5:30AM Tue', 'Closed ⋅ Opens 10AM Tue',
#        'Closed ⋅ Opens 4AM', 'Closes soon ⋅ 9PM ⋅ Opens 11AM Mon',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 11AM Mon',
#        'Closes soon ⋅ 9PM ⋅ Opens 5AM Mon', 'Closed ⋅ Opens 5:30AM Wed',
#        'Open ⋅ Closes 2:15AM', 'Closes soon ⋅ 6PM ⋅ Opens 10AM Thu',
#        'Closes soon ⋅ 3PM ⋅ Opens 7:30AM Mon',
#        'Closes soon ⋅ 12AM ⋅ Opens 11:30AM Sun',
#        'Closed ⋅ Opens 11:30AM Sun', 'Closes soon ⋅ 9PM ⋅ Opens 12PM Sun',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 5PM Wed',
#        'Closes soon ⋅ 7:30PM ⋅ Opens 12PM Sun',
#        'Closes soon ⋅ 7PM ⋅ Opens 10AM Sun',
#        'Closes soon ⋅ 5PM ⋅ Opens 8AM Sun',
#        'Open ⋅ Closes 3AM ⋅ Reopens 11AM', 'Closed ⋅ Opens 12PM Sat',
#        'Closed ⋅ Opens 10AM Sat', 'Closes soon ⋅ 11PM ⋅ Opens 11AM Sat',
#        'Closes soon ⋅ 9PM ⋅ Opens 11AM Sat', 'Closed ⋅ Opens 5AM Sat',
#        'Closes soon ⋅ 7PM ⋅ Opens 5AM Sat', 'Opens soon ⋅ 4AM',
#        'Closed ⋅ Opens 11:30AM Fri', 'Closed ⋅ Opens 10:30AM Fri',
#        'Closes soon ⋅ 12AM ⋅ Opens 7AM Fri', 'Closed ⋅ Opens 4:30AM Fri',
#        'Closes soon ⋅ 10PM ⋅ Opens 11AM Fri', 'Closed ⋅ Opens 4AM Fri',
#        'Closes soon ⋅ 10PM ⋅ Opens 6AM Fri',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 11AM Fri',
#        'Closes soon ⋅ 8PM ⋅ Opens 11AM Fri',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 11:45AM Fri',
#        'Closes soon ⋅ 7:30PM ⋅ Opens 11AM Fri',
#        'Closes soon ⋅ 6PM ⋅ Opens 8AM Fri',
#        'Closes soon ⋅ 4PM ⋅ Opens 7AM Fri', 'Open ⋅ Closes 11:45PM',
#        'Open ⋅ Closes 5:45PM', 'Opens soon ⋅ 10AM', 'Opens soon ⋅ 9AM',
#        'Opens soon ⋅ 7:30AM', 'Closed ⋅ Opens 4:30AM Thu',
#        'Closed ⋅ Opens 7:30AM Thu', 'Closes soon ⋅ 9PM ⋅ Opens 9AM Thu',
#        'Closes soon ⋅ 9PM ⋅ Opens 7AM Thu', 'Opens soon ⋅ 3PM',
#        'Open ⋅ Closes 3PM ⋅ Reopens 5PM',
#        'Closes soon ⋅ 10AM ⋅ Reopens 11:30AM', 'Open ⋅ Closes 11:30AM',
#        'Open ⋅ Closes 1:45PM', 'Closed ⋅ Opens 4:30PM Thu',
#        'Closed ⋅ Opens 5:45AM Wed', 'Closed ⋅ Opens 6:30AM Wed',
#        'Closes soon ⋅ 10PM ⋅ Opens 4AM Wed',
#        'Closes soon ⋅ 10PM ⋅ Opens 10AM Wed',
#        'Closes soon ⋅ 10PM ⋅ Opens 11AM Wed',
#        'Closes soon ⋅ 10PM ⋅ Opens 5AM Wed', 'Closed ⋅ Opens 4AM Wed',
#        'Closes soon ⋅ 8PM ⋅ Opens 5AM Wed', 'Closed ⋅ Opens 5:30PM Thu',
#        'Closes soon ⋅ 7PM ⋅ Opens 5AM Wed',
#        'Closes soon ⋅ 2PM ⋅ Reopens 4:30PM', 'Opens soon ⋅ 10:30AM',
#        'Closed ⋅ Opens 1PM Wed', 'Closes soon ⋅ 12AM ⋅ Opens 11AM Tue',
#        'Closes soon ⋅ 12AM ⋅ Opens 10:30AM Tue',
#        'Closed ⋅ Opens 4:30AM Tue', 'Closes soon ⋅ 8PM ⋅ Opens 12PM Tue',
#        'Closed ⋅ Opens 2PM Tue', 'Closes soon ⋅ 7PM ⋅ Opens 5AM Tue',
#        'Closed ⋅ Opens 4:30PM Wed', 'Closed ⋅ Opens 5:30AM Tue',
#        'Closes soon ⋅ 4PM ⋅ Opens 9AM Tue', 'Closed ⋅ Opens 1PM Thu',
#        'Closes soon ⋅ 1PM ⋅ Opens 7AM Tue', 'Closed ⋅ Opens 2:30PM',
#        'Opens soon ⋅ 5:30AM', 'Closes soon ⋅ 9:45PM ⋅ Opens 11:15AM Mon',
#        'Closes soon ⋅ 10PM ⋅ Opens 11AM Mon',
#        'Closes soon ⋅ 9:30PM ⋅ Opens 11AM Tue',
#        'Closes soon ⋅ 8PM ⋅ Opens 9AM Wed', 'Closed ⋅ Opens 6:30AM Tue',
#        'Closed ⋅ Opens 3PM Mon', 'Open ⋅ Closes 3AM',
#        'Open ⋅ Closes 12:30PM', 'Open ⋅ Closes 11AM',
#        'Open ⋅ Closes 4AM ⋅ Reopens 10AM',
#        'Closes soon ⋅ 12AM ⋅ Opens 12PM Sun',
#        'Closes soon ⋅ 12AM ⋅ Opens 4PM Sun', 'Closed ⋅ Opens 5PM Sun',
#        'Closes soon ⋅ 10PM ⋅ Opens 3PM Mon',
#        'Closes soon ⋅ 9:30PM ⋅ Opens 12PM Sun',
#        'Closed ⋅ Opens 6:30AM Sun',
#        'Closes soon ⋅ 10PM ⋅ Opens 11:30AM Sun',
#        'Closes soon ⋅ 9PM ⋅ Opens 11AM Sun', 'Closed ⋅ Opens 4AM Sun',
#        'Closed ⋅ Opens 5:30AM Sun', 'Closes soon ⋅ 8PM ⋅ Opens 6AM Sun',
#        'Closes soon ⋅ 7PM ⋅ Opens 4AM Sun',
#        'Closes soon ⋅ 7PM ⋅ Opens 5AM Sun',
#        'Closes soon ⋅ 1PM ⋅ Opens 6AM Mon', 'Open ⋅ Closes 1:30PM',
#        'Closed ⋅ Opens 4PM Sat', 'Closed ⋅ Opens 6:30AM Sat',
#        'Closed ⋅ Opens 4AM Sat', 'Closes soon ⋅ 10PM ⋅ Opens 10:30AM Sat',
#        'Closes soon ⋅ 10PM ⋅ Opens 9AM Sat',
#        'Closes soon ⋅ 9:30PM ⋅ Opens 11AM Sat',
#        'Closes soon ⋅ 10PM ⋅ Opens 10AM Sat',
#        'Closes soon ⋅ 10PM ⋅ Opens 8AM Sat', 'Closed ⋅ Opens 12:30PM Sat',
#        'Closes soon ⋅ 9PM ⋅ Opens 6AM Sat',
#        'Closes soon ⋅ 8PM ⋅ Opens 11:30AM Sat', 'Closed ⋅ Opens 9:30PM',
#        'Closes soon ⋅ 2:30PM ⋅ Opens 8AM Sat',
#        'Closed ⋅ Opens 7:30AM Sun', 'Open ⋅ Closes 3PM ⋅ Reopens 4PM',
#        'Closes soon ⋅ 1PM ⋅ Opens 8AM Sat',
#        'Closes soon ⋅ 12AM ⋅ Opens 10AM Fri', 'Closed ⋅ Opens 4:30PM Fri',
#        'Closes soon ⋅ 12AM ⋅ Opens 11AM Fri',
#        'Closes soon ⋅ 11PM ⋅ Opens 7AM Fri', 'Closed ⋅ Opens 2PM Fri',
#        'Closes soon ⋅ 10PM ⋅ Opens 10:45AM Fri', 'Closed ⋅ Opens 3PM Fri',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 1PM Fri',
#        'Closes soon ⋅ 8PM ⋅ Opens 7AM Fri', 'Opens soon ⋅ 8:30AM',
#        'Closed ⋅ Opens 10:15AM', 'Closed ⋅ Opens 5:30PM Tue',
#        'Open ⋅ Closes 2:30PM ⋅ Reopens 5PM', 'Open ⋅ Closes 7:45PM',
#        'Opens soon ⋅ 4:30AM', 'Closes soon ⋅ 4AM ⋅ Reopens 6:30AM',
#        'Closes soon ⋅ 3AM ⋅ Reopens 7AM',
#        'Closes soon ⋅ 1AM ⋅ Reopens 2PM', 'Closed ⋅ Opens 4:30PM Mon',
#        'Closes soon ⋅ 12AM ⋅ Opens 9AM Mon',
#        'Closes soon ⋅ 9:30PM ⋅ Opens 9:30AM Mon',
#        'Closes soon ⋅ 8:45PM ⋅ Opens 11AM Tue', 'Open ⋅ Closes 9:15PM',
#        'Closes soon ⋅ 7:45PM ⋅ Opens 11AM Mon',
#        'Closes soon ⋅ 7PM ⋅ Opens 9AM Mon',
#        'Closes soon ⋅ 6PM ⋅ Opens 4:30AM Mon', 'Open ⋅ Closes 5:30PM',
#        'Open ⋅ Closes 3:30PM', 'Closed ⋅ Opens 5:30PM Wed',
#        'Closed ⋅ Opens 1PM Mon', 'Closed ⋅ Opens 10:30PM',
#        'Closes soon ⋅ 2:30AM ⋅ Reopens 11AM',
#        'Open ⋅ Closes 9PM ⋅ Reopens 11:30PM', 'Closed ⋅ Opens 3PM Sun',
#        'Closed ⋅ Opens 4PM Sun', 'Closes soon ⋅ 12AM ⋅ Opens 11AM Sun',
#        'Closes soon ⋅ 11:30PM ⋅ Opens 10:30AM Sun',
#        'Closed ⋅ Opens 12:30PM Sun',
#        'Closes soon ⋅ 10PM ⋅ Opens 11AM Sun',
#        'Closes soon ⋅ 9:30PM ⋅ Opens 3PM Sun',
#        'Closes soon ⋅ 9PM ⋅ Opens 10:45AM Sun',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 12PM Sun',
#        'Closes soon ⋅ 8PM ⋅ Opens 11AM Mon',
#        'Closes soon ⋅ 7:30PM ⋅ Opens 9AM Sun',
#        'Open ⋅ Closes 2:30PM ⋅ Reopens 4PM',
#        'Closes soon ⋅ 2AM ⋅ Reopens 11AM',
#        'Closes soon ⋅ 12AM ⋅ Opens 11:30AM Sat',
#        'Closes soon ⋅ 12AM ⋅ Opens 6AM Sat', 'Closed ⋅ Opens 5:30AM Sat',
#        'Closes soon ⋅ 10:30PM ⋅ Opens 11AM Sat',
#        'Closes soon ⋅ 10:30PM ⋅ Opens 11:30AM Sat',
#        'Closes soon ⋅ 10PM ⋅ Opens 5PM Sat', 'Closed ⋅ Opens 4:30PM Sat',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 5:30AM Sat', 'Open ⋅ Closes 2:30PM',
#        'Open ⋅ Closes 3PM ⋅ Reopens 4:30PM',
#        'Closes soon ⋅ 1PM ⋅ Opens 6AM Sat', 'Open ⋅ Closes 10:45PM',
#        'Opens soon ⋅ 10:45AM', 'Closed ⋅ Opens 12AM Sun',
#        'Closes soon ⋅ 1AM ⋅ Reopens 11:30AM',
#        'Closes soon ⋅ 1AM ⋅ Reopens 8AM',
#        'Closes soon ⋅ 11PM ⋅ Opens 11AM Fri',
#        'Closes soon ⋅ 10PM ⋅ Opens 10AM Fri',
#        'Closes soon ⋅ 10PM ⋅ Opens 4PM Fri',
#        'Closes soon ⋅ 10PM ⋅ Opens 12PM Fri',
#        'Closed ⋅ Opens 10:45AM Fri',
#        'Closes soon ⋅ 9:45PM ⋅ Opens 11AM Fri',
#        'Closes soon ⋅ 7PM ⋅ Opens 5AM Fri',
#        'Closes soon ⋅ 7:30PM ⋅ Opens 7AM Fri',
#        'Open ⋅ Closes 12PM ⋅ Reopens 4PM',
#        'Closes soon ⋅ 10PM ⋅ Opens 11AM Thu',
#        'Closes soon ⋅ 10PM ⋅ Opens 5AM Thu',
#        'Closes soon ⋅ 9:30PM ⋅ Opens 11AM Thu',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 5PM Thu',
#        'Closes soon ⋅ 8PM ⋅ Opens 11AM Thu',
#        'Closes soon ⋅ 8PM ⋅ Opens 10AM Thu',
#        'Closes soon ⋅ 7PM ⋅ Opens 4:30AM Thu',
#        'Closes soon ⋅ 3PM ⋅ Opens 7AM Thu',
#        'Closes soon ⋅ 9PM ⋅ Opens 9AM Wed',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 8AM Wed',
#        'Closes soon ⋅ 9PM ⋅ Opens 10:30AM Wed',
#        'Closes soon ⋅ 8PM ⋅ Opens 11AM Wed',
#        'Closes soon ⋅ 8PM ⋅ Opens 10:30AM Wed',
#        'Closes soon ⋅ 8PM ⋅ Opens 4:30AM Wed', 'Opens soon ⋅ 4:30PM',
#        'Closes soon ⋅ 2PM ⋅ Opens 6:30AM Wed',
#        'Open ⋅ Closes 2AM ⋅ Reopens 10:30AM',
#        'Closes soon ⋅ 12AM ⋅ Opens 10AM Tue', 'Closed ⋅ Opens 6PM Wed',
#        'Closes soon ⋅ 7:30PM ⋅ Opens 5AM Tue',
#        'Closes soon ⋅ 3PM ⋅ Opens 7AM Tue',
#        'Closes soon ⋅ 1AM ⋅ Reopens 4PM',
#        'Closes soon ⋅ 2PM ⋅ Opens 7AM Mon',
#        'Closes soon ⋅ 1:30PM ⋅ Opens 7:30AM Wed',
#        'Closes soon ⋅ 9PM ⋅ Opens 4PM Wed',
#        'Closes soon ⋅ 7PM ⋅ Opens 5:30AM Sun',
#        'Closes soon ⋅ 7PM ⋅ Opens 6AM Sun', 'Open ⋅ Closes 9AM Sun',
#        'Closed ⋅ Opens 8:30AM Sun',
#        'Closes soon ⋅ 2:30PM ⋅ Opens 7:30AM Sun',
#        'Closes soon ⋅ 2:30PM ⋅ Reopens 4:30PM', 'Opens soon ⋅ 9:30AM',
#        'Open ⋅ Closes 2AM ⋅ Reopens 7AM',
#        'Closes soon ⋅ 11:30PM ⋅ Opens 12AM Sat',
#        'Closes soon ⋅ 10PM ⋅ Opens 11:30AM Sat',
#        'Closes soon ⋅ 10:30PM ⋅ Opens 12PM Sat',
#        'Closes soon ⋅ 10:30PM ⋅ Opens 4PM Sat', 'Open ⋅ Closes 9AM Sat',
#        'Closes soon ⋅ 1PM ⋅ Opens 7AM Sat',
#        'Open ⋅ Closes 3:30PM ⋅ Reopens 4:30PM',
#        'Closed ⋅ Opens 6:30AM Fri', 'Closes soon ⋅ 2PM ⋅ Opens 7AM Fri',
#        'Open ⋅ Closes 2AM ⋅ Reopens 4PM',
#        'Closes soon ⋅ 9:30PM ⋅ Opens 11:30AM Thu',
#        'Closes soon ⋅ 8PM ⋅ Opens 3:30PM Thu',
#        'Closes soon ⋅ 8PM ⋅ Opens 10:30AM Thu',
#        'Closes soon ⋅ 8PM ⋅ Opens 10:45AM Thu',
#        'Closes soon ⋅ 2PM ⋅ Opens 6:30AM Thu',
#        'Closes soon ⋅ 4AM ⋅ Reopens 9AM', 'Closed ⋅ Opens 10:30AM Wed',
#        'Closed ⋅ Opens 9AM Wed', 'Closes soon ⋅ 9PM ⋅ Opens 11AM Wed',
#        'Closes soon ⋅ 8PM ⋅ Opens 12PM Wed',
#        'Closes soon ⋅ 8PM ⋅ Opens 3PM Wed',
#        'Closes soon ⋅ 7PM ⋅ Opens 11AM Wed',
#        'Closes soon ⋅ 7:30PM ⋅ Opens 4:30PM Wed',
#        'Open ⋅ Closes 3AM ⋅ Reopens 10PM',
#        'Closes soon ⋅ 10PM ⋅ Opens 11:30AM Tue',
#        'Closes soon ⋅ 9PM ⋅ Opens 8AM Tue',
#        'Closes soon ⋅ 8:30PM ⋅ Opens 4PM Thu',
#        'Closes soon ⋅ 6PM ⋅ Opens 9AM Tue',
#        'Closes soon ⋅ 4PM ⋅ Opens 8AM Wed',
#        'Closes soon ⋅ 12:45PM ⋅ Opens 6AM Tue',
#        'Closes soon ⋅ 2AM ⋅ Reopens 3:30PM',
#        'Closes soon ⋅ 11PM ⋅ Opens 9:30AM Mon',
#        'Closes soon ⋅ 11PM ⋅ Opens 11AM Mon', 'Closed ⋅ Opens 4AM Mon',
#        'Closes soon ⋅ 9PM ⋅ Opens 4AM Wed',
#        'Closes soon ⋅ 8PM ⋅ Opens 11:30AM Mon', 'Closed ⋅ Opens 10PM',
#        'Closes soon ⋅ 6PM ⋅ Opens 5:30AM Mon',
#        'Closes soon ⋅ 2:30PM ⋅ Reopens 4PM', 'Closed ⋅ Opens 6PM Tue',
#        'Closes soon ⋅ 2AM ⋅ Reopens 6:30AM',
#        'Open ⋅ Closes 2AM ⋅ Reopens 6:30AM',
#        'Closes soon ⋅ 10PM ⋅ Opens 4AM Sun',
#        'Closes soon ⋅ 10PM ⋅ Opens 9AM Sun',
#        'Closes soon ⋅ 10PM ⋅ Opens 6:30AM Sun',
#        'Closes soon ⋅ 9PM ⋅ Opens 11:30AM Sun', 'Open ⋅ Closes 10:20PM',
#        'Closes soon ⋅ 8:15PM ⋅ Opens 12PM Sun',
#        'Closes soon ⋅ 8PM ⋅ Opens 5AM Sun',
#        'Closes soon ⋅ 6PM ⋅ Opens 5:30AM Sun',
#        'Closes soon ⋅ 6PM ⋅ Opens 6AM Sun', 'Open ⋅ Closes 2:45AM',
#        'Closes soon ⋅ 1:30PM ⋅ Opens 7AM Sun',
#        'Closes soon ⋅ 1AM ⋅ Reopens 11AM',
#        'Closes soon ⋅ 12AM ⋅ Opens 10AM Sat',
#        'Closes soon ⋅ 12AM ⋅ Opens 12PM Sat',
#        'Closes soon ⋅ 11PM ⋅ Opens 12PM Sat',
#        'Closes soon ⋅ 11PM ⋅ Opens 10:30AM Sat',
#        'Closes soon ⋅ 10:45PM ⋅ Opens 12PM Sat',
#        'Closes soon ⋅ 9PM ⋅ Opens 4AM Sat',
#        'Closes soon ⋅ 9PM ⋅ Opens 5AM Sat',
#        'Closes soon ⋅ 9PM ⋅ Opens 11:30AM Sat',
#        'Closes soon ⋅ 2:30PM ⋅ Opens 6AM Sat',
#        'Closes soon ⋅ 3PM ⋅ Opens 5:30AM Sat',
#        'Closes soon ⋅ 8PM ⋅ Opens 11:30AM Fri',
#        'Closes soon ⋅ 5:30PM ⋅ Opens 9AM Fri',
#        'Closes soon ⋅ 8PM ⋅ Opens 5:30AM Thu',
#        'Closes soon ⋅ 8PM ⋅ Opens 4:30AM Thu',
#        'Closes soon ⋅ 2:30PM ⋅ Opens 10:45AM Thu',
#        'Closes soon ⋅ 10:30AM ⋅ Reopens 4PM',
#        'Open ⋅ Closes 11AM ⋅ Reopens 5PM', nan], dtype=object)

# %%
df_expanded_clean['price'].unique()
# Out:
# array(['$$', None, '$', '$$$', '₩₩', '₩', '₩₩₩', '$$$$'], dtype=object)

# %%
df_expanded_clean['hours'].astype(str).unique()
# Out:
# array(["[['Thursday', '11AM–8PM'], ['Friday', '11AM–10PM'], ['Saturday', '11AM–10PM'], ['Sunday', '4–10PM'], ['Monday', 'Closed'], ['Tuesday', '11AM–8PM'], ['Wednesday', '11AM–8PM']]",
#        'None',
#        "[['Wednesday', '11AM–8:30PM'], ['Thursday', '11AM–8:30PM'], ['Friday', '11AM–9PM'], ['Saturday', '11AM–9PM'], ['Sunday', '11AM–8:30AM'], ['Monday', '11AM–8:30AM'], ['Tuesday', '11AM–8:30PM']]",
#        ...,
#        "[['Friday', '11:30AM–8PM'], ['Saturday', '4–8PM'], ['Sunday', '4–8PM'], ['Monday', '11:30AM–8PM'], ['Tuesday', '11:30AM–8PM'], ['Wednesday', '11:30AM–8PM'], ['Thursday', '11:30AM–8PM']]",
#        "[['Friday', '7AM–8PM'], ['Saturday', '7AM–8PM'], ['Sunday', '11AM–8PM'], ['Monday', '7AM–8PM'], ['Tuesday', '7AM–8PM'], ['Wednesday', '7AM–8PM'], ['Thursday', '7AM–8PM']]",
#        "[['Thursday', 'Closed'], ['Friday', 'Closed'], ['Saturday', 'Closed'], ['Sunday', '3:35–3:36AM'], ['Monday', 'Closed'], ['Tuesday', 'Closed'], ['Wednesday', 'Closed']]"],
#       dtype=object)

# %%
df_expanded_clean['Service options'].astype(str).unique()
# Out:
# array(["['Takeout', 'Delivery']", "['Delivery']",
#        "['Delivery', 'Takeout']", "['Delivery', 'Takeout', 'Dine-in']",
#        "['Takeout', 'Dine-in']",
#        "['In-store shopping', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Takeout', 'Dine-in', 'Delivery']",
#        "['Drive-through', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Curbside pickup', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Curbside pickup', 'In-store pickup', 'In-store shopping', 'Takeout', 'Delivery']",
#        "['No-contact delivery', 'Delivery', 'Takeout', 'Dine-in']", 'nan',
#        "['Outdoor seating', 'Delivery', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Delivery', 'Takeout', 'Dine-in']",
#        "['Takeout']", "['Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'Delivery', 'Takeout', 'Dine-in']",
#        "['Drive-through', 'Takeout', 'Delivery']",
#        "['Outdoor seating', 'Takeout', 'Delivery']",
#        "['Delivery', 'In-store pickup', 'In-store shopping', 'Takeout']",
#        "['Outdoor seating', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'No-contact delivery', 'Delivery', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Takeout']",
#        "['No-contact delivery', 'Takeout', 'Delivery']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['In-store shopping', 'Takeout', 'Delivery']",
#        "['Outdoor seating', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'Takeout', 'Dine-in', 'Delivery']",
#        "['No-contact delivery', 'Delivery', 'Takeout']",
#        "['Curbside pickup', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Delivery', 'In-store shopping']",
#        "['In-store pickup', 'In-store shopping']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Takeout']",
#        "['In-store shopping', 'Delivery']",
#        "['In-store pickup', 'In-store shopping', 'Takeout']",
#        "['No-contact delivery', 'Takeout', 'Dine-in']",
#        "['No-contact delivery', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'No-contact delivery', 'Delivery', 'Takeout']",
#        "['In-store pickup', 'In-store shopping', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup']", "['Delivery', 'Dine-in', 'Takeout']",
#        "['Delivery', 'Dine-in']", "['Dine-in', 'Delivery', 'Takeout']",
#        "['Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Delivery', 'Takeout']", "['Dine-in']",
#        "['Curbside pickup', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'In-store pickup', 'In-store shopping']",
#        "['Curbside pickup', 'Takeout', 'Delivery']",
#        "['Curbside pickup', 'Delivery', 'Takeout']",
#        "['No-contact delivery', 'Delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Takeout', 'Delivery']",
#        "['No-contact delivery', 'Delivery', 'In-store shopping', 'Same-day delivery']",
#        "['In-store shopping', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'Dine-in', 'Delivery', 'Takeout']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery']",
#        "['Curbside pickup', 'Delivery']", "['In-store shopping']",
#        "['No-contact delivery', 'Delivery', 'In-store shopping', 'Takeout']",
#        "['Outdoor seating', 'Curbside pickup', 'Delivery', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'Delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['Drive-through', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'In-store pickup', 'In-store shopping', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'In-store shopping', 'Delivery']",
#        "['Outdoor seating']", "['Delivery', 'Takeaway']",
#        "['No-contact delivery', 'Delivery', 'Takeaway', 'Dine-in']",
#        "['Delivery', 'Takeaway', 'Dine-in']", "['Takeaway', 'Dine-in']",
#        "['Outdoor seating', 'No-contact delivery', 'Delivery', 'Takeaway', 'Dine-in']",
#        "['Takeaway', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'Takeaway', 'Dine-in', 'Delivery']",
#        "['Curbside pickup', 'Takeaway', 'Dine-in']",
#        "['Curbside pickup', 'Delivery', 'Takeaway', 'Dine-in']",
#        "['In-store pickup', 'In-store shopping', 'Delivery']",
#        "['Outdoor seating', 'Delivery', 'Takeaway', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Delivery', 'Takeaway', 'Dine-in']",
#        "['Takeaway', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'Delivery', 'Takeaway', 'Dine-in']",
#        "['Curbside pickup', 'Takeaway', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeaway']",
#        "['Outdoor seating', 'Dine-in', 'Delivery', 'Takeaway']",
#        "['Outdoor seating', 'Takeaway', 'Dine-in']",
#        "['No-contact delivery', 'Delivery', 'Takeaway']",
#        "['Drive-through', 'Takeaway', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'Delivery', 'Drive-through', 'Takeaway', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeout']",
#        "['Curbside pickup', 'No-contact delivery', 'Takeout']",
#        "['No-contact delivery', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Delivery', 'In-store shopping', 'Takeout']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Takeaway', 'Dine-in']",
#        "['Outdoor seating', 'Takeaway', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'Delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['No-contact delivery', 'Delivery']",
#        "['Outdoor seating', 'Takeaway', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Takeaway', 'Dine-in', 'Delivery']",
#        "['Delivery', 'Drive-through', 'Takeaway', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeaway']",
#        "['Outdoor seating', 'Curbside pickup', 'Dine-in', 'Delivery', 'Takeaway']",
#        "['Outdoor seating', 'No-contact delivery', 'Delivery', 'Takeaway']",
#        "['In-store pick-up', 'In-store shopping', 'Takeaway', 'Dine-in', 'Delivery']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeaway', 'Dine-in']",
#        "['Curbside pickup', 'Delivery', 'Drive-through', 'Takeaway', 'Dine-in']",
#        "['Takeaway', 'Delivery', 'Dine-in']",
#        "['No-contact delivery', 'Delivery', 'In-store pickup', 'In-store shopping']",
#        "['Outdoor seating', 'Drive-through', 'Takeaway', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Curbside pickup', 'Delivery', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'Takeaway', 'Dine-in']",
#        "['Delivery', 'In-store pickup', 'In-store shopping']",
#        "['Outdoor seating', 'Delivery', 'Takeaway']",
#        "['Curbside pickup', 'Delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'In-store pickup', 'In-store shopping']",
#        "['Curbside pickup', 'No-contact delivery', 'Takeout', 'Dine-in']",
#        "['In-store pickup', 'Takeout', 'Delivery']",
#        "['Delivery', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['In-store pickup', 'In-store shopping', 'Takeout', 'Delivery']",
#        "['No-contact delivery', 'Delivery', 'In-store pickup', 'Takeout', 'Same-day delivery', 'Dine-in']",
#        "['Curbside pickup', 'Delivery', 'In-store pickup', 'In-store shopping', 'Same-day delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Delivery', 'Takeout']",
#        "['Curbside pickup', 'Drive-through', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Drive-through', 'Delivery']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['No-contact delivery', 'Delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Same-day delivery', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'Drive-through', 'Takeout', 'Dine-in', 'Delivery']",
#        "['No-contact delivery', 'Delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'Drive-through', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'Drive-through', 'Takeout', 'Dine-in', 'Delivery']",
#        "['No-contact delivery', 'Delivery', 'In-store pickup', 'In-store shopping', 'Takeout']",
#        "['Outdoor seating', 'Dine-in']",
#        "['No-contact delivery', 'Delivery', 'Drive-through', 'Takeout']",
#        "['Delivery', 'Drive-through', 'Takeout']",
#        "['Outdoor seating', 'Curbside pickup', 'Delivery', 'Takeout']",
#        "['Delivery', 'In-store shopping', 'Same-day delivery']",
#        "['Curbside pickup', 'No-contact delivery', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Drive-through', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'Delivery', 'In-store pickup', 'In-store shopping']",
#        "['No-contact delivery', 'Delivery', 'Same-day delivery']",
#        "['Curbside pickup', 'Delivery', 'In-store pickup', 'In-store shopping', 'Takeout']",
#        "['Takeout', 'Delivery', 'In-store shopping', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'Takeout', 'Delivery']",
#        "['Outdoor seating', 'Drive-through', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeout']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'In-store shopping']",
#        "['Curbside pickup', 'Dine-in', 'Delivery', 'Takeout']",
#        "['No-contact delivery', 'Delivery', 'Drive-through', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Dine-in', 'Takeout']",
#        "['Outdoor seating', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Dine-in', 'Delivery']",
#        "['In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Delivery', 'In-store pickup', 'In-store shopping', 'Same-day delivery']",
#        "['Drive-through', 'In-store shopping', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through', 'Dine-in', 'Takeout']",
#        "['Outdoor seating', 'Curbside pickup', 'Drive-through', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'Delivery', 'In-store shopping']",
#        "['No-contact delivery', 'Drive-through', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Curbside pickup', 'Takeout']",
#        "['Curbside pickup', 'No-contact delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Same-day delivery', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'No-contact delivery', 'Takeout', 'Dine-in']",
#        "['Drive-through', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'No-contact delivery', 'Delivery', 'Drive-through', 'Dine-in', 'Takeout']",
#        "['Curbside pickup', 'In-store shopping', 'Delivery']",
#        "['Curbside pickup', 'In-store pickup', 'In-store shopping', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through', 'Takeout']",
#        "['Curbside pickup', 'In-store pickup', 'Takeout', 'Delivery']",
#        "['Curbside pickup', 'Delivery', 'In-store shopping', 'Takeout']",
#        "['Drive-through', 'Takeout']",
#        "['In-store shopping', 'Takeout', 'Dine-in']",
#        "['Drive-through', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in', 'Delivery']",
#        "['In-store pickup', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Takeout', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'Drive-through', 'Takeout', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Takeout', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'Takeout']",
#        "['Delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in', 'Same-day delivery']",
#        "['Online appointments']",
#        "['In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['No-contact delivery', 'Delivery', 'In-store shopping', 'Takeout', 'Same-day delivery', 'Dine-in']",
#        "['Delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Same-day delivery']",
#        "['In-store shopping', 'Takeout']",
#        "['No-contact delivery', 'Delivery', 'Drive-through', 'Dine-in', 'Takeout']",
#        "['Drive-through', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'No-contact delivery', 'Drive-through', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Curbside pickup', 'No-contact delivery', 'In-store pickup', 'In-store shopping', 'Delivery']",
#        "['Outdoor seating', 'No-contact delivery', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['No-contact delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Delivery']",
#        "['In-store pickup', 'Delivery']",
#        "['Curbside pickup', 'Drive-through', 'Takeout', 'Delivery']",
#        "['Outdoor seating', 'Delivery', 'In-store pickup', 'In-store shopping', 'Takeout', 'Dine-in']",
#        "['Curbside pickup', 'In-store pickup', 'Takeout', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Delivery', 'Dine-in']",
#        "['Outdoor seating', 'Curbside pickup', 'Drive-through', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Outdoor seating', 'Curbside pickup', 'No-contact delivery', 'Drive-through', 'Takeout', 'Dine-in', 'Delivery']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'Drive-through']",
#        "['Curbside pickup', 'Drive-through', 'Takeout', 'Dine-in']",
#        "['No-contact delivery', 'Delivery', 'In-store pickup', 'In-store shopping', 'Same-day delivery']",
#        "['Curbside pickup', 'No-contact delivery', 'Delivery', 'In-store pickup', 'In-store shopping', 'Same-day delivery']",
#        "['In-store pickup', 'Takeout', 'Delivery', 'In-store shopping', 'Dine-in']",
#        "['No-contact delivery', 'Delivery', 'Dine-in']"], dtype=object)

# %%
df_expanded_clean['Accessibility'].astype(str).unique()
# Out:
# array(["['Wheelchair accessible entrance']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible seating']",
#        'nan', "['Wheelchair accessible elevator']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible parking lot']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible restroom']",
#        "['Wheelchair accessible seating']",
#        "['Wheelchair accessible seating', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible restroom', 'Wheelchair accessible entrance']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible seating', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance']",
#        "['Wheelchair-accessible entrance']",
#        "['Wheelchair-accessible car park', 'Wheelchair-accessible entrance', 'Wheelchair-accessible seating', 'Wheelchair-accessible toilet']",
#        "['Wheelchair-accessible car park', 'Wheelchair-accessible entrance', 'Wheelchair-accessible seating']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible toilet']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible seating']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible seating', 'Wheelchair-accessible car park']",
#        "['Wheelchair-accessible car park', 'Wheelchair-accessible entrance', 'Wheelchair-accessible toilet']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible seating', 'Wheelchair-accessible toilet']",
#        "['Wheelchair-accessible car park', 'Wheelchair-accessible entrance', 'Wheelchair-accessible lift', 'Wheelchair-accessible seating', 'Wheelchair-accessible toilet']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible seating', 'Wheelchair-accessible toilet', 'Wheelchair-accessible car park']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible lift', 'Wheelchair-accessible seating', 'Wheelchair-accessible toilet']",
#        "['Wheelchair-accessible car park', 'Wheelchair-accessible lift', 'Wheelchair-accessible seating', 'Wheelchair-accessible toilet']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible restroom', 'Wheelchair accessible parking lot', 'Wheelchair accessible seating']",
#        "['Wheelchair-accessible car park', 'Wheelchair-accessible entrance']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot']",
#        "['Wheelchair-accessible seating']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible lift', 'Wheelchair-accessible toilet']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible car park']",
#        "['Wheelchair-accessible toilet', 'Wheelchair-accessible entrance']",
#        "['Wheelchair-accessible entrance', 'Wheelchair-accessible lift', 'Wheelchair-accessible seating', 'Wheelchair-accessible toilet', 'Wheelchair-accessible car park']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair accessible entrance', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible seating', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible restroom', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible seating', 'Wheelchair accessible entrance']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible entrance']",
#        "['Wheelchair accessible seating', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible entrance', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible seating', 'Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair accessible entrance']",
#        "['Wheelchair accessible seating', 'Wheelchair accessible entrance', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair rental']",
#        "['Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair accessible entrance']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible seating', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible seating', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible entrance', 'Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible parking lot', 'Wheelchair accessible entrance', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom', 'Wheelchair accessible seating']",
#        "['Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible restroom', 'Wheelchair accessible entrance', 'Wheelchair accessible parking lot']",
#        "['Wheelchair accessible entrance', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair rental']",
#        "['Assisted listening devices', 'Wheelchair accessible entrance']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible entrance', 'Wheelchair accessible seating', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom']",
#        "['Wheelchair accessible elevator', 'Wheelchair accessible parking lot', 'Wheelchair accessible restroom', 'Wheelchair accessible seating', 'Wheelchair accessible entrance']"],
#       dtype=object)

# %%
df_expanded_clean['Offerings'].astype(str).unique()
# Out:
# array(["['Comfort food', 'Late-night food', 'Vegetarian options']",
#        "['Coffee', 'Comfort food', 'Healthy options', 'Organic dishes', 'Quick bite', 'Vegetarian options']",
#        "['Coffee', 'Comfort food', 'Healthy options', 'Quick bite', 'Small plates', 'Vegetarian options']",
#        ...,
#        '[\'Alcohol\', \'All you can eat\', \'Beer\', \'Braille menu\', \'Cocktails\', \'Coffee\', \'Comfort food\', \'Happy hour drinks\', \'Happy hour food\', \'Hard liquor\', "Kids\' menu", \'Late-night food\', \'Organic dishes\', \'Small plates\', \'Vegetarian options\', \'Wine\']',
#        '[\'Alcohol\', \'Coffee\', \'Comfort food\', \'Food\', \'Food at bar\', \'Happy hour food\', "Kids\' menu", \'Late-night food\', \'Quick bite\']',
#        '[\'Coffee\', \'Halal food\', \'Healthy options\', "Kids\' menu", \'Late-night food\', \'Quick bite\', \'Vegetarian options\']'],
#       dtype=object)

# %%
df_expanded_clean['Dining options'].astype(str).unique()
# Out:
# array(["['Lunch', 'Dinner', 'Dessert']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Dessert']", "['Dessert']", nan,
#        "['Breakfast', 'Lunch', 'Catering', 'Dessert', 'Seating']",
#        "['Lunch', 'Dinner', 'Catering', 'Dessert', 'Seating']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Dessert', 'Seating']",
#        "['Breakfast']", "['Breakfast', 'Lunch', 'Dessert']",
#        "['Breakfast', 'Dessert']",
#        "['Lunch', 'Dinner', 'Catering', 'Dessert']",
#        "['Breakfast', 'Lunch', 'Dinner']", "['Seating']",
#        "['Lunch', 'Dinner', 'Seating']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Catering', 'Dessert', 'Seating']",
#        "['Lunch', 'Dinner']", "['Breakfast', 'Lunch']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Counter service', 'Dessert']",
#        "['Lunch', 'Dinner', 'Catering']", "['Lunch', 'Catering']",
#        "['Lunch', 'Dinner', 'Dessert', 'Seating']",
#        "['Lunch', 'Catering', 'Dessert']",
#        "['Lunch', 'Dinner', 'Catering', 'Seating']", "['Dinner']",
#        "['Dinner', 'Catering', 'Dessert', 'Seating']",
#        "['Breakfast', 'Dinner', 'Catering', 'Dessert', 'Seating']",
#        "['Lunch']", "['Dinner', 'Dessert']", "['Catering', 'Dessert']",
#        "['Lunch', 'Dinner', 'Catering', 'Counter service']",
#        "['Lunch', 'Counter service']", "['Catering']",
#        "['Lunch', 'Catering', 'Dessert', 'Seating']",
#        "['Lunch', 'Dinner', 'Counter service']",
#        "['Breakfast', 'Lunch', 'Dessert', 'Seating']",
#        "['Lunch', 'Dessert']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Catering', 'Dessert']",
#        "['Breakfast', 'Dinner', 'Catering', 'Dessert']",
#        "['Breakfast', 'Counter service']", "['Breakfast', 'Dinner']",
#        "['Dinner', 'Seating']", "['Counter service', 'Dessert']",
#        "['Dessert', 'Seating']", "['Lunch', 'Catering', 'Seating']",
#        "['Breakfast', 'Lunch', 'Counter service', 'Dessert']",
#        "['Catering', 'Dessert', 'Seating']", "['Catering', 'Seating']",
#        "['Breakfast', 'Seating']", "['Lunch', 'Seating']",
#        "['Dinner', 'Dessert', 'Seating']",
#        "['Breakfast', 'Dinner', 'Dessert', 'Seating']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Seating']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Catering', 'Seating']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Catering']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Counter service', 'Dessert', 'Seating']",
#        "['Breakfast', 'Dessert', 'Seating']",
#        "['Breakfast', 'Dinner', 'Dessert']",
#        "['Breakfast', 'Lunch', 'Seating']",
#        "['Dinner', 'Catering', 'Seating']",
#        "['Breakfast', 'Lunch', 'Catering', 'Dessert']",
#        "['Dinner', 'Catering', 'Dessert']",
#        "['Outside food allowed', 'Seating']",
#        "['Breakfast', 'Catering', 'Dessert', 'Seating']",
#        "['Breakfast', 'Lunch', 'Catering', 'Seating']",
#        "['Lunch', 'Dessert', 'Seating']",
#        "['Catering', 'Counter service', 'Seating']",
#        "['Lunch', 'Dinner', 'Counter service', 'Dessert']",
#        "['Breakfast', 'Catering', 'Dessert']",
#        "['Lunch', 'Dinner', 'Catering', 'Dessert', 'Outside food allowed', 'Seating']",
#        "['Dinner', 'Catering']", "['Breakfast', 'Dinner', 'Catering']",
#        "['Breakfast', 'Catering', 'Seating']",
#        "['Breakfast', 'Dinner', 'Seating']",
#        "['Breakfast', 'Dinner', 'Catering', 'Seating']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Catering', 'Counter service', 'Dessert']",
#        "['Breakfast', 'Lunch', 'Catering']",
#        "['Lunch', 'Dinner', 'Catering', 'Dessert', 'Pay ahead']",
#        "['Outside food allowed']", "['Breakfast', 'Catering']",
#        "['Dessert', 'Outside food allowed']",
#        "['Dessert', 'Outside food allowed', 'Seating']",
#        "['Lunch', 'Dinner', 'Dessert', 'Outside food allowed', 'Seating']"],
#       dtype=object)

# %%
df_expanded_clean['Payments'].astype(str).unique()
# Out:
# array(["['Debit cards']", nan, "['NFC mobile payments']",
#        "['Debit cards', 'Credit cards']",
#        "['Debit cards', 'NFC mobile payments', 'Credit cards']",
#        "['Debit cards', 'NFC mobile payments']",
#        "['Checks', 'Debit cards', 'Credit cards']", "['Credit cards']",
#        "['Cash-only']", "['Cash-only', 'Debit cards']",
#        "['Cash-only', 'Credit cards']",
#        "['Cash-only', 'Debit cards', 'Credit cards']",
#        "['Cash-only', 'Checks', 'Debit cards', 'NFC mobile payments']",
#        "['Cash-only', 'Checks', 'Debit cards', 'Credit cards']",
#        "['NFC mobile payments', 'Credit cards']",
#        "['Checks', 'Debit cards']",
#        "['Checks', 'Debit cards', 'NFC mobile payments']",
#        "['Cash-only', 'NFC mobile payments']", "['Checks']",
#        "['Cash-only', 'Debit cards', 'NFC mobile payments']",
#        "['Checks', 'Debit cards', 'NFC mobile payments', 'Credit cards']",
#        "['Cash-only', 'Debit cards', 'NFC mobile payments', 'Credit cards']",
#        "['Cash-only', 'Checks']",
#        "['Cash only', 'NFC mobile payments', 'Credit cards']",
#        "['Cash only']", "['Checks', 'Credit cards']",
#        "['Cheques', 'Debit cards', 'NFC mobile payments', 'Credit cards']",
#        "['Cheques', 'Debit cards', 'Credit cards']",
#        "['Cheques', 'NFC mobile payments', 'Credit cards']",
#        "['Cash only', 'Debit cards']",
#        "['Cash-only', 'Checks', 'Debit cards']",
#        "['Checks', 'NFC mobile payments']",
#        "['Cash-only', 'Checks', 'Debit cards', 'NFC mobile payments', 'Credit cards']",
#        "['Checks', 'NFC mobile payments', 'Credit cards']",
#        "['Cash-only', 'NFC mobile payments', 'Credit cards']"],
#       dtype=object)

# %%
df_expanded_clean['Highlights'].astype(str).unique()
# Out:
# array([nan, "['Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Great coffee']", "['Fast service']",
#        "['Great beer selection', 'Great cocktails']",
#        "['Fast service', 'Great coffee', 'Great tea selection']",
#        "['Great coffee', 'Great dessert']", "['Great dessert']",
#        "['LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great coffee']", "['LGBTQ friendly']",
#        "['Fireplace', 'Great coffee']",
#        "['Great beer selection', 'Great cocktails', 'LGBTQ friendly']",
#        "['Great coffee', 'Great wine list']", "['Great cocktails']",
#        "['Fireplace', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list']",
#        "['Live music']", "['Great dessert', 'LGBTQ friendly']",
#        "['Great cocktails', 'Live music']",
#        "['Fast service', 'Great beer selection', 'Great coffee', 'Great dessert', 'Great wine list']",
#        "['Great cocktails', 'Great wine list']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great wine list']",
#        "['Great beer selection']",
#        "['Fireplace', 'Live music', 'Sports']",
#        "['Fast service', 'Great cocktails']",
#        "['Great coffee', 'LGBTQ friendly']", "['Serves local specialty']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Sports']",
#        "['Active military discounts', 'Live performances', 'Play area']",
#        "['Transgender safespace']",
#        "['Fast service', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fireplace', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Sports']", "['LGBTQ friendly', 'Live music']",
#        "['Great coffee', 'Great tea selection']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Live music', 'Sports']",
#        "['Fireplace']",
#        "['Great coffee', 'Great dessert', 'Great wine list']",
#        "['Great coffee', 'Great dessert', 'Live music', 'Sports']",
#        "['Great bar food']",
#        "['Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list', 'LGBTQ friendly']",
#        "['Fast service', 'Great tea selection']",
#        "['Fireplace', 'LGBTQ friendly']",
#        "['Karaoke', 'Live music', 'Live performances']",
#        "['Fast service', 'Great coffee', 'LGBTQ friendly']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'LGBTQ friendly']",
#        "['Great cocktails', 'Great dessert', 'Great wine list']",
#        "['LGBTQ friendly', 'Sports', 'Transgender safespace']",
#        "['Great tea selection']",
#        "['Fireplace', 'LGBTQ friendly', 'Live music', 'Sports', 'Transgender safespace']",
#        "['Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list']",
#        "['Fireplace', 'Rooftop seating']",
#        "['Great beer selection', 'Great cocktails', 'Live music']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Live music', 'Serves local specialty', 'Sports']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Karaoke', 'LGBTQ friendly', 'Live music', 'Live performances', 'Transgender safespace']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Live music', 'Sports', 'Trivia night']",
#        "['Fast service', 'Great coffee', 'Great tea selection', 'LGBTQ friendly']",
#        "['Great beer selection', 'Great dessert']", "['Great produce']",
#        "['Great dessert', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fireplace', 'LGBTQ friendly', 'Live music', 'Transgender safespace']",
#        "['LGBTQ friendly', 'Live music', 'Transgender safespace']",
#        "['Fireplace', 'Great coffee', 'LGBTQ friendly', 'Live music', 'Transgender safespace']",
#        "['Great cocktails', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'LGBTQ friendly']",
#        "['Great dessert', 'Great wine list']",
#        "['Fast service', 'Great beer selection', 'Great cocktails']",
#        "['Great cocktails', 'Great dessert', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great dessert', 'Great tea selection']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great dessert']",
#        "['Fireplace', 'LGBTQ friendly', 'Sports', 'Transgender safespace']",
#        "['Great cocktails', 'Great coffee']",
#        "['Fast service', 'Live performances']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Live music']",
#        "['Rooftop seating']",
#        "['Great coffee', 'Great dessert', 'Live music']",
#        "['Fast service', 'Sports']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great wine list', 'LGBTQ friendly', 'Rooftop seating']",
#        "['Fireplace', 'LGBTQ friendly', 'Live music']",
#        "['Great dessert', 'Great tea selection']",
#        "['Fast service', 'Fireplace']", "['Live music', 'Sports']",
#        "['Great wine list']",
#        "['Fast service', 'Great cocktails', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Great cocktails', 'Great wine list', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fireplace', 'Sports']",
#        "['Great beer selection', 'Live music']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Live music', 'Transgender safespace']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert']",
#        "['Great coffee', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Fast service', 'Great coffee', 'Great tea selection', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great coffee', 'Great dessert']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert']",
#        "['Great cocktails', 'Great coffee', 'Great tea selection']",
#        "['Sports', 'Transgender safespace']",
#        "['Rooftop seating', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Sports']",
#        "['Great cocktails', 'Great dessert', 'Great wine list', 'LGBTQ friendly', 'Rooftop seating', 'Transgender safespace']",
#        "['Great tea selection', 'LGBTQ-friendly', 'Transgender safe space']",
#        "['Fast service', 'Great coffee', 'Great tea selection', 'LGBTQ-friendly']",
#        "['Great dessert', 'LGBTQ-friendly', 'Transgender safe space']",
#        "['Fast service', 'Karaoke', 'Live music', 'Live performances', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Sports', 'Transgender safespace']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Sport']",
#        "['Great coffee', 'Great dessert', 'LGBTQ-friendly', 'Transgender safe space']",
#        "['Great dessert', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'Sport']",
#        "['Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Great coffee', 'LGBTQ-friendly', 'Transgender safe space']",
#        "['Fast service', 'Live music', 'Sport']",
#        "['Fast service', 'Live music']",
#        "['Fast service', 'Fireplace', 'Great coffee', 'Great tea selection', 'LGBTQ-friendly', 'Sport', 'Transgender safe space']",
#        "['LGBTQ friendly', 'Rooftop seating']",
#        "['Fast service', 'Play area']",
#        "['Fireplace', 'Great dessert', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Great dessert', 'Great tea selection', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Great dessert', 'LGBTQ friendly', 'Sports', 'Transgender safespace']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Live music', 'Sport']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Great tea selection', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Great cocktails', 'Great dessert']",
#        "['Fireplace', 'Great coffee', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list']",
#        "['Fireplace', 'Great cocktails', 'Great coffee', 'Great dessert', 'Live music', 'Sport']",
#        "['Fireplace', 'Great tea selection']",
#        "['Great beer selection', 'Great cocktails', 'LGBTQ-friendly', 'Live music', 'Sport']",
#        "['LGBTQ-friendly', 'Transgender safe space']",
#        "['Bar games', 'Fast service', 'Great beer selection']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Great tea selection', 'Serves local specialty']",
#        "['Bar games', 'Fast service', 'Live music', 'Sport']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list']",
#        "['Fast service', 'LGBTQ-friendly', 'Sport', 'Transgender safe space']",
#        "['Active military discounts', 'Fast service', 'Great coffee', 'Play area']",
#        "['LGBTQ friendly', 'Live music', 'Sports', 'Transgender safespace']",
#        "['Fast service', 'LGBTQ friendly', 'Live music', 'Live performances', 'Sports']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great cocktails', 'Great coffee', 'Great dessert', 'Live music', 'Live performances', 'Sport']",
#        "['Fast service', 'Great tea selection', 'LGBTQ-friendly', 'Transgender safe space']",
#        "['LGBTQ-friendly', 'Live music']",
#        "['Fireplace', 'Serves local specialty']",
#        "['Fireplace', 'Great coffee', 'Great dessert']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Live music', 'Sports']",
#        "['LGBTQ-friendly']",
#        "['LGBTQ-friendly', 'Live music', 'Sport', 'Transgender safe space']",
#        "['Great cocktails', 'Great coffee', 'Great dessert', 'Live music']",
#        "['LGBTQ-friendly', 'Sport', 'Transgender safe space']",
#        "['Great beer selection', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'LGBTQ-friendly']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails']",
#        "['LGBTQ friendly', 'Sports']",
#        "['Fast service', 'LGBTQ friendly']",
#        "['Great tea selection', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list']",
#        "['Fireplace', 'LGBTQ friendly', 'Live music', 'Live performances']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Live performances', 'Sports', 'Transgender safespace', 'Trivia night']",
#        "['Great cocktails', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fireplace', 'Great cocktails', 'Great wine list', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Great coffee', 'Transgender safespace']",
#        "['Bar games', 'Fireplace', 'Karaoke', 'Live music', 'Live performances', 'Trivia night']",
#        "['Great dessert', 'Live music', 'Sports']",
#        "['Great tea selection', 'LGBTQ friendly']",
#        "['Great dessert', 'Sports']",
#        "['Great beer selection', 'Great wine list', 'Live music']",
#        "['Great coffee', 'Great tea selection', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great coffee', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fireplace', 'LGBTQ friendly', 'Rooftop seating', 'Transgender safespace']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Great cocktails', 'Great wine list', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'LGBTQ friendly', 'Rooftop seating', 'Transgender safespace']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list']",
#        "['Fast service', 'Great beer selection', 'Great coffee', 'Great tea selection']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Sports', 'Transgender safespace']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Karaoke', 'LGBTQ friendly', 'Sports', 'Transgender safespace']",
#        "['Great cocktails', 'LGBTQ friendly', 'Live music', 'Transgender safespace']",
#        "['Play area']",
#        "['Fireplace', 'Great cocktails', 'Great coffee', 'Great dessert', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails']",
#        "['Fireplace', 'LGBTQ friendly', 'Live music', 'Rooftop seating', 'Transgender safespace']",
#        "['Bar games', 'Fast service', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'Live music']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'LGBTQ friendly']",
#        "['Fast service', 'LGBTQ friendly', 'Rooftop seating', 'Transgender safespace']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great wine list', 'LGBTQ friendly']",
#        "['Great coffee', 'Great dessert', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fireplace', 'LGBTQ friendly', 'Live music', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Sports']",
#        "['Bar games', 'Fast service', 'Live music', 'Sports']",
#        "['Great cocktails', 'Great dessert', 'Great wine list', 'LGBTQ friendly', 'Sports']",
#        "['Great coffee', 'Live music']", "['Bar games', 'Live music']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Live music', 'Sports', 'Transgender safespace']",
#        "['Fast service', 'Great dessert', 'Sports']",
#        "['Bar games', 'Live music', 'Sports']",
#        "['Great cocktails', 'Great wine list', 'LGBTQ friendly', 'Live music']",
#        "['Active military discounts', 'Fast service', 'Great coffee']",
#        "['Active military discounts']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'LGBTQ friendly', 'Live music', 'Transgender safespace']",
#        "['Great cocktails', 'Great tea selection']",
#        "['Great coffee', 'Great dessert', 'Great tea selection', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Live music', 'Sports', 'Trivia night']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great tea selection', 'Great wine list', 'LGBTQ friendly']",
#        "['Fast service', 'Fireplace', 'Great coffee']",
#        "['Fast service', 'Fireplace', 'Live music']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list']",
#        "['Fast service', 'LGBTQ friendly', 'Live music', 'Transgender safespace']",
#        "['Great coffee', 'Great dessert', 'Sports']",
#        "['Bar games', 'Fast service', 'Great cocktails']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Live music', 'Sports']",
#        "['Great coffee', 'Great dessert', 'LGBTQ friendly', 'Live music', 'Sports', 'Transgender safespace']",
#        "['Great coffee', 'Great dessert', 'Great tea selection', 'LGBTQ friendly']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Karaoke', 'Live music', 'Live performances', 'Sports']",
#        "['Fast service', 'Great wine list']",
#        "['Fireplace', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list', 'Live music']",
#        "['Great coffee', 'Great dessert', 'LGBTQ friendly']",
#        "['Fireplace', 'Great dessert']",
#        "['Great coffee', 'LGBTQ friendly', 'Live music', 'Sports', 'Transgender safespace']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Sports', 'Trivia night']",
#        "['Great beer selection', 'Great cocktails', 'Live music', 'Sports']",
#        "['Great dessert', 'LGBTQ friendly', 'Live music', 'Sports', 'Transgender safespace']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Sports']",
#        "['Fireplace', 'LGBTQ friendly', 'Live performances', 'Transgender safespace']",
#        "['Fireplace', 'Great coffee', 'Great dessert', 'Live music']",
#        "['Fast service', 'Fireplace', 'LGBTQ friendly', 'Sports']",
#        "['Fireplace', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Fast service', 'Great cocktails', 'Great coffee', 'Great dessert']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert', 'LGBTQ friendly', 'Sports', 'Transgender safespace']",
#        "['Fast service', 'Live music', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Live music']",
#        "['Great bar food', 'Live performances']",
#        "['Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Live music']",
#        "['Bar games', 'Fast service', 'Live music', 'Sports', 'Trivia night']",
#        "['Fireplace', 'Great coffee', 'Great dessert', 'LGBTQ friendly', 'Transgender safespace']",
#        "['Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Karaoke']",
#        "['Fireplace', 'Great tea selection', 'LGBTQ friendly']",
#        "['Fast service', 'Great beer selection']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'LGBTQ friendly', 'Sports', 'Transgender safespace']",
#        "['Fast service', 'Great coffee', 'Great tea selection', 'Live music', 'Live performances']",
#        "['Great coffee', 'Great dessert', 'LGBTQ friendly', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Live music', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great tea selection']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Live music', 'Sports']",
#        "['Great coffee', 'Great dessert', 'LGBTQ friendly', 'Sports']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Live music', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Live music']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Karaoke', 'LGBTQ friendly', 'Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Great dessert', 'LGBTQ friendly', 'Rooftop seating', 'Transgender safespace']",
#        "['Fast service', 'Fireplace', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great tea selection', 'LGBTQ friendly', 'Live music', 'Sports', 'Transgender safespace']",
#        "['Great beer selection', 'Great cocktails', 'LGBTQ friendly', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Live music', 'Rooftop seating']",
#        "['Fast service', 'Great beer selection', 'Live performances', 'Sports']",
#        "['Great cocktails', 'Great coffee', 'Great dessert', 'Sports']",
#        "['Great cocktails', 'Great coffee', 'Great dessert']",
#        "['Fast service', 'LGBTQ friendly', 'Sports']",
#        "['Great coffee', 'LGBTQ friendly', 'Sports']",
#        "['Fast service', 'Great coffee', 'Play area']",
#        "['Bar games', 'Live music', 'Live performances']",
#        "['Great beer selection', 'Great dessert', 'Great wine list']",
#        "['Bar games', 'Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Great beer selection', 'Sports']",
#        "['Fast service', 'Great coffee', 'Live music', 'Live performances', 'Sports']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Live music', 'Sports']",
#        "['Fireplace', 'Great coffee', 'Great dessert', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Great coffee', 'Great dessert', 'Great tea selection', 'Live music']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Live music', 'Sports']",
#        "['Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Sports']",
#        "['Great dessert', 'Serves local specialty', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great coffee', 'Great tea selection']",
#        "['Bar games']", "['Great tea selection', 'Sports']",
#        "['Great cocktails', 'Great dessert', 'Sports']",
#        "['Fireplace', 'Great beer selection']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert', 'Sports']",
#        "['Fast service', 'Great dessert', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great tea selection', 'Great wine list']",
#        "['Fireplace', 'Great coffee', 'Great dessert', 'Great tea selection', 'Live music']",
#        "['Fast service', 'Great cocktails', 'Sports']",
#        "['Great cocktails', 'Great tea selection', 'Live music']",
#        "['Fast service', 'Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list']",
#        "['Great bar food', 'Great cocktails']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Great wine list']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Karaoke', 'Live music']",
#        "['Bar games', 'Karaoke', 'Live music', 'Live performances', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Live music', 'Rooftop seating', 'Sports']",
#        "['Great coffee', 'Live music', 'Live performances', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great dessert', 'Sports']",
#        "['Bar games', 'Karaoke', 'Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great cocktails', 'Great coffee', 'Sports']",
#        "['Great bar food', 'Live music', 'Sports', 'Trivia night']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Sports']",
#        "['Great wine list', 'Live music']",
#        "['Great bar food', 'Great beer selection', 'Great cocktails', 'Live music']",
#        "['Fast service', 'Live performances', 'Sports']",
#        "['Great cocktails', 'Live music', 'Sports']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great coffee']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Great tea selection', 'Great wine list', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'Sports']",
#        "['Fast service', 'Great coffee', 'Great tea selection', 'Sports']",
#        "['Fast service', 'Live music', 'Live performances', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'Rooftop seating']",
#        "['Great cocktails', 'Great dessert', 'Great wine list', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great coffee', 'Great dessert', 'Great tea selection', 'Great wine list']",
#        "['Great coffee', 'Great dessert', 'Great tea selection', 'Sports']",
#        "['Great coffee', 'Sports']",
#        "['Fireplace', 'Great dessert', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Live music', 'Sports']",
#        "['Bar games', 'Great bar food', 'Live music', 'Live performances']",
#        "['Bar games', 'Fast service', 'Sports', 'Trivia night']",
#        "['Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Bar games', 'Live music', 'Live performances', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great dessert', 'Great wine list', 'Sports']",
#        "['Live music', 'Live performances', 'Sports']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Live music']",
#        "['Serves local specialty', 'Sports']",
#        "['Great tea selection', 'Live music', 'Sports']",
#        "['Bar games', 'Fast service', 'Great dessert', 'Sports']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list']",
#        "['Sports', 'Trivia night']",
#        "['Fast service', 'Great bar food', 'Great cocktails', 'Great dessert', 'Live performances', 'Sports', 'Trivia night']",
#        "['Live music', 'Live performances']",
#        "['Fireplace', 'Great cocktails', 'Great wine list', 'Live music', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great tea selection', 'Live music']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Karaoke', 'Live music', 'Live performances', 'Sports']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great coffee', 'Great tea selection', 'Live music', 'Live performances']",
#        "['Great dessert', 'Rooftop seating']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great dessert']",
#        "['Fast service', 'Fireplace', 'Great dessert']",
#        "['Fast service', 'Great bar food', 'Great cocktails', 'Great coffee', 'Great dessert', 'Live music', 'Live performances', 'Sports']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Great tea selection']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Live music', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great coffee', 'Great dessert', 'Live music']",
#        "['Fast service', 'Great cocktails', 'Great tea selection', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list', 'Live music']",
#        "['Live performances']",
#        "['Fast service', 'Fireplace', 'Great cocktails', 'Sports']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Sports']",
#        "['Fireplace', 'Great cocktails', 'Great coffee', 'Great dessert', 'Sports']",
#        "['Fireplace', 'Great dessert', 'Live music']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great coffee', 'Great dessert', 'Live music', 'Sports']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Karaoke', 'Live music', 'Sports', 'Trivia night']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Sports', 'Trivia night']",
#        "['Fast service', 'Fireplace', 'Great cocktails', 'Great coffee']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Live music', 'Live performances', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great wine list']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list']",
#        "['Fast service', 'Great bar food', 'Great cocktails', 'Great coffee', 'Great dessert', 'Sports']",
#        "['Fireplace', 'Great tea selection', 'Sports']",
#        "['Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Sports', 'Trivia night']",
#        "['Fast service', 'Fireplace', 'Rooftop seating']",
#        "['Great beer selection', 'Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Fast service', 'Great cocktails', 'Live music']",
#        "['Great bar food', 'Great cocktails', 'Live performances']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Sports']",
#        "['Bar games', 'Live music', 'Rooftop seating', 'Sports']",
#        "['Fireplace', 'Great dessert', 'Rooftop seating']",
#        "['Fast service', 'Fireplace', 'Great dessert', 'Sports']",
#        "['Great cocktails', 'Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Sports']",
#        "['Fireplace', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Fast service', 'Great bar food', 'Great cocktails', 'Great dessert', 'Sports']",
#        "['Fireplace', 'Live music', 'Live performances']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Live music', 'Live performances', 'Sports']",
#        "['Fireplace', 'Great dessert', 'Great tea selection']",
#        "['Fast service', 'Great bar food', 'Great dessert', 'Live music', 'Sports']",
#        "['Live music', 'Rooftop seating']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Sports']",
#        "['Great bar food', 'Great cocktails', 'Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Fast service', 'Great beer selection', 'Great wine list']",
#        "['Fireplace', 'Great coffee', 'Live music', 'Serves local specialty']",
#        "['Fast service', 'Great cocktails', 'Great coffee', 'Great dessert', 'Sports']",
#        "['Fast service', 'Great dessert', 'Live music', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great coffee']",
#        "['Great cocktails', 'Great dessert', 'Live music', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Live music', 'Sports', 'Trivia night']",
#        "['Fireplace', 'Great cocktails', 'Karaoke', 'Sports']",
#        "['Fireplace', 'Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Great coffee', 'Great tea selection', 'Live music']",
#        "['Fast service', 'Sports', 'Trivia night']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Great tea selection', 'Live music', 'Live performances']",
#        "['Fast service', 'Great dessert', 'Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Fireplace', 'Great cocktails', 'Great coffee', 'Great dessert']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'Trivia night']",
#        "['Great beer selection', 'Great cocktails', 'Rooftop seating']",
#        "['Bar games', 'Trivia night']",
#        "['Fast service', 'Fireplace', 'Live music', 'Sports']",
#        "['Great cocktails', 'Rooftop seating']",
#        "['Fast service', 'Live music', 'Rooftop seating', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Sports']",
#        "['Bar games', 'Fast service', 'Fireplace', 'Great bar food', 'Live music', 'Sports', 'Trivia night']",
#        "['Great beer selection', 'Great cocktails', 'Great dessert', 'Live music']",
#        "['Fireplace', 'Great cocktails', 'Sports']",
#        "['Great beer selection', 'Great wine list']",
#        "['Great cocktails', 'Great tea selection', 'Great wine list']",
#        "['Bar games', 'Sports']",
#        "['Live music', 'Serves local specialty']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list', 'Sports']",
#        "['Fireplace', 'Great cocktails', 'Great coffee', 'Great wine list']",
#        "['Great bar food', 'Great cocktails', 'Karaoke', 'Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Live music']",
#        "['Fast service', 'Great cocktails', 'Great dessert']",
#        "['Fireplace', 'Great coffee', 'Great dessert', 'Live music', 'Sports']",
#        "['Fast service', 'Great tea selection', 'Sports']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Live music']",
#        "['Fast service', 'Great bar food', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Live music']",
#        "['Karaoke', 'Live music', 'Sports', 'Trivia night']",
#        "['Active military discounts', 'Play area']",
#        "['Great dessert', 'Serves local specialty']",
#        "['Fireplace', 'Great cocktails', 'Great dessert', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great coffee', 'Trivia night']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great dessert', 'Great wine list', 'Live music', 'Sports']",
#        "['Fast service', 'Live music', 'Live performances']",
#        "['Great cocktails', 'Great coffee', 'Great tea selection', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great coffee', 'Great dessert']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great wine list']",
#        "['Fast service', 'Great bar food', 'Live music']",
#        "['Fireplace', 'Great coffee', 'Rooftop seating']",
#        "['Fast service', 'Trivia night']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Live music', 'Trivia night']",
#        "['Fireplace', 'Great cocktails', 'Live music']",
#        "['Fast service', 'Fireplace', 'Great tea selection']",
#        "['Bar games', 'Fast service', 'Great coffee', 'Great dessert', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Karaoke', 'Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Great coffee', 'Live music', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great beer selection', 'Great cocktails', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Great wine list', 'Sports']",
#        "['Great cocktails', 'Great tea selection', 'Great wine list', 'Sports']",
#        "['Fast service', 'Great bar food', 'Great cocktails', 'Great coffee', 'Rooftop seating', 'Sports']",
#        "['Fireplace', 'Great coffee', 'Great dessert', 'Rooftop seating']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great tea selection', 'Great wine list', 'Live music']",
#        "['Great beer selection', 'Great cocktails', 'Great wine list', 'Live music', 'Sports']",
#        "['Fast service', 'Great bar food', 'Great cocktails', 'Live music', 'Sports']",
#        "['Bar games', 'Fast service', 'Live music', 'Live performances', 'Sports']",
#        "['Great beer selection', 'Great cocktails', 'Great tea selection', 'Great wine list']",
#        "['Fireplace', 'Great coffee', 'Great tea selection', 'Sports']",
#        "['Active military discounts', 'Fast service', 'Play area']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great cocktails', 'Sports', 'Trivia night']",
#        "['Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Great wine list']",
#        "['Fast service', 'Great tea selection', 'Live performances']",
#        "['Great cocktails', 'Great coffee', 'Sports']",
#        "['Fast service', 'Serves local specialty', 'Sports']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great tea selection', 'Great wine list', 'Live music']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Karaoke', 'Live performances', 'Serves local specialty']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Live music']",
#        "['Great cocktails', 'Great dessert', 'Live music']",
#        "['Fast service', 'Great bar food']",
#        "['Great dessert', 'Live music', 'Rooftop seating']",
#        "['3D movies']",
#        "['Fireplace', 'Great cocktails', 'Live music', 'Sports']",
#        "['Fast service', 'Great coffee', 'Great dessert', 'Great tea selection', 'Live music']",
#        "['Fast service', 'Fireplace', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Sports']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great coffee', 'Great tea selection', 'Karaoke', 'Live music', 'Live performances', 'Trivia night']",
#        "['Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails']",
#        "['Bar games', 'Fast service', 'Great beer selection', 'Great cocktails', 'Sports', 'Trivia night']",
#        "['Fast service', 'Fireplace', 'Great bar food', 'Sports']",
#        "['Fast service', 'Great bar food', 'Great dessert', 'Sports', 'Trivia night']",
#        "['Great beer selection', 'Great wine list', 'Live music', 'Sports']",
#        "['Great cocktails', 'Great tea selection', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Live music', 'Sports', 'Trivia night']",
#        "['Bar games', 'Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Sports']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Live music', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Live music']",
#        "['Active military discounts', 'Live performances']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Live music', 'Live performances']",
#        "['Fast service', 'Great cocktails', 'Great tea selection', 'Live music', 'Sports']",
#        "['Fireplace', 'Great tea selection', 'Live music']",
#        "['Fast service', 'Great bar food', 'Great beer selection', 'Great cocktails', 'Great wine list', 'Live performances', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great coffee', 'Great dessert', 'Sports']",
#        "['Fast service', 'Great bar food', 'Live music', 'Sports']",
#        "['Fast service', 'Live music', 'Live performances', 'Sports', 'Trivia night']",
#        "['Fast service', 'Fireplace', 'Great cocktails']",
#        "['Great beer selection', 'Great cocktails', 'Rooftop seating', 'Sports']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Live performances', 'Trivia night']",
#        "['Fast service', 'Great tea selection', 'Live music']",
#        "['Fast service', 'Great beer selection', 'Great cocktails', 'Great tea selection', 'Great wine list']",
#        "['Fireplace', 'Great coffee', 'Great tea selection']",
#        "['Fireplace', 'Great coffee', 'Great dessert', 'Great tea selection', 'Sports']",
#        "['Fast service', 'Fireplace', 'Great cocktails', 'Great dessert']",
#        "['Fast service', 'Rooftop seating']",
#        "['Great cocktails', 'Great coffee', 'Great dessert', 'Live music', 'Sports']",
#        "['Fast service', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great tea selection']",
#        "['Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list', 'Live music', 'Sports']",
#        "['Great beer selection', 'Great coffee', 'Great tea selection']",
#        "['Bar games', 'Cabaret', 'Fast service', 'Great coffee', 'Great dessert', 'Live performances', 'Sports', 'Trivia night']",
#        "['Cabaret', 'Fireplace', 'Great coffee']",
#        "['Bar games', 'Karaoke', 'Live music', 'Sports']",
#        "['Great cocktails', 'Great coffee', 'Live music']",
#        "['Fireplace', 'Great beer selection', 'Great cocktails', 'Great coffee', 'Great dessert', 'Great wine list', 'Live music', 'Sports']"],
#       dtype=object)

# %%
df_expanded_clean['Popular for'].astype(str).unique()
# Out:
# array([nan, "['Breakfast', 'Lunch', 'Dinner', 'Solo dining']",
#        "['Lunch', 'Dinner', 'Solo dining']",
#        "['Breakfast', 'Lunch', 'Solo dining']", "['Solo dining']",
#        "['Dinner', 'Solo dining']", "['Lunch', 'Solo dining']",
#        "['Breakfast', 'Solo dining']", "['Lunch', 'Dinner']",
#        "['Breakfast', 'Dinner', 'Solo dining']",
#        "['Breakfast', 'Lunch', 'Dinner']", "['Lunch']",
#        "['Breakfast', 'Lunch']", "['Breakfast']", "['Dinner']",
#        "['Breakfast', 'Solo dining', 'Good for working on laptop']",
#        "['Breakfast', 'Lunch', 'Solo dining', 'Good for working on laptop']",
#        "['Breakfast', 'Lunch', 'Dinner', 'Solo dining', 'Good for working on laptop']",
#        "['Solo dining', 'Good for working on laptop']",
#        "['Lunch', 'Dinner', 'Solo dining', 'Good for working on laptop']",
#        "['Lunch', 'Solo dining', 'Good for working on laptop']"],
#       dtype=object)

# %%
df_expanded_clean['Amenities'].unique()
# Out:
# array([nan, "['Good for kids', 'Restroom']", "['Good for kids']",
#        "['Good for kids', 'High chairs', 'Restroom', 'Wi-Fi']",
#        "['Gender-neutral restroom', 'Good for kids', 'Restroom']",
#        "['Good for kids', 'High chairs']", "['Bar onsite', 'Restroom']",
#        "['Good for kids', 'Restroom', 'Wi-Fi']",
#        "['Bar onsite', 'Good for kids', 'High chairs']",
#        "['Restroom', 'Wi-Fi']", "['Bar onsite']",
#        "['Good for kids', 'High chairs', 'Restroom']",
#        "['Public restroom', 'Restroom']",
#        "['Gender-neutral restroom', 'Good for kids']",
#        "['Bar onsite', 'Good for kids']",
#        "['Good for kids', 'High chairs', 'Wi-Fi']",
#        "['Bar onsite', 'High chairs', 'Restroom', 'Wi-Fi']", "['Wi-Fi']",
#        "['Good for kids', 'Wi-Fi']",
#        "['Gender-neutral restroom', 'Good for kids', 'High chairs', 'Restroom']",
#        "['Bar onsite', 'High chairs']",
#        "['Gender-neutral restroom', 'Good for kids', 'High chairs', 'Wi-Fi']",
#        "['Bar onsite', 'Good for kids', 'High chairs', 'Restroom']",
#        "['Gender-neutral restroom', 'Good for kids', 'Restroom', 'Wi-Fi']",
#        "['Bar onsite', 'Good for kids', 'High chairs', 'Restroom', 'Wi-Fi']",
#        "['High chairs']", "['Restroom']",
#        "['Bar onsite', 'Good for kids', 'High chairs', 'Wi-Fi']",
#        "['Good for kids', 'Restaurant', 'Restroom']",
#        "['Bar onsite', 'High chairs', 'Restroom']",
#        "['Gender-neutral restroom']",
#        "['Gender-neutral restroom', 'Good for kids', 'High chairs', 'Restroom', 'Wi-Fi']",
#        "['Gender-neutral restroom', 'Good for kids', 'High chairs']",
#        "['Bar onsite', 'Good for kids', 'Restroom', 'Wi-Fi']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Restroom', 'Wi-Fi']",
#        "['Bar onsite', 'Restroom', 'Wi-Fi']",
#        "['Gender-neutral restroom', 'Restroom', 'Wi-Fi']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Restaurant']",
#        "['High chairs', 'Wi-Fi']",
#        "['Bar onsite', 'Gender-neutral restroom', 'High chairs']",
#        "['Bar onsite', 'Good for kids', 'Restroom']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Restroom']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Good for kids', 'High chairs', 'Restroom', 'Wi-Fi']",
#        "['Gender-neutral restroom', 'Good for kids', 'Wi-Fi']",
#        "['Bar onsite', 'Gender-neutral restroom', 'High chairs', 'Restroom']",
#        "['Bar onsite', 'Gender-neutral restroom', 'High chairs', 'Restroom', 'Wi-Fi']",
#        "['High chairs', 'Restroom', 'Wi-Fi']",
#        "['Bar onsite', 'Good for kids', 'Wi-Fi']",
#        "['Good for kids', 'High chairs', 'Toilets']",
#        "['Good for kids', 'Toilets', 'Wi-Fi']", "['Toilets']",
#        "['Good for kids', 'High chairs', 'Toilets', 'Wi-Fi']",
#        "['Bar on site', 'Good for kids', 'High chairs', 'Toilets', 'Wi-Fi']",
#        "['Bar on site']", "['Good for kids', 'Toilets']",
#        "['Gender-neutral toilets', 'Good for kids', 'High chairs', 'Toilets']",
#        "['Bar on site', 'Gender-neutral toilets', 'Good for kids', 'High chairs', 'Toilets', 'Wi-Fi']",
#        "['Gender-neutral toilets', 'High chairs', 'Toilets']",
#        "['Good for kids', 'Restaurant', 'Toilets']",
#        "['Bar on site', 'High chairs', 'Toilets', 'Wi-Fi']",
#        "['Bar onsite', 'Wi-Fi']",
#        "['Bar on site', 'Good for kids', 'High chairs']",
#        "['Bar on site', 'Good for kids', 'High chairs', 'Toilets']",
#        "['Bar on site', 'Wi-Fi']", "['High chairs', 'Restroom']",
#        "['Gender-neutral toilets', 'Good for kids', 'High chairs', 'Toilets', 'Wi-Fi']",
#        "['High chairs', 'Toilets']",
#        "['Bar on site', 'Gender-neutral toilets', 'Good for kids', 'High chairs', 'Toilets']",
#        "['Bar on site', 'Good for kids', 'Toilets']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Good for kids', 'High chairs', 'Restroom']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Good for kids', 'High chairs', 'Wi-Fi']",
#        "['Gender-neutral restroom', 'Restroom']",
#        "['Bar onsite', 'High chairs', 'Wi-Fi']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Good for kids', 'Wi-Fi']",
#        "['Gender-neutral restroom', 'High chairs', 'Restroom', 'Wi-Fi']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Good for kids', 'Restroom']",
#        "['Gender-neutral restroom', 'High chairs', 'Restroom']",
#        "['Gender-neutral restroom', 'High chairs']",
#        "['Bar onsite', 'Gender-neutral restroom', 'Wi-Fi']",
#        "['Public restroom']",
#        "['Good for kids', 'Restaurant', 'Restroom', 'Wi-Fi']",
#        "['Good for kids', 'Restaurant']",
#        "['Bar onsite', 'Restaurant', 'Restroom', 'Wi-Fi']",
#        "['Public restroom', 'Wi-Fi']", "['Restaurant']",
#        "['Bar onsite', 'Good for kids', 'Restaurant']",
#        "['Good for kids', 'Restaurant', 'Wi-Fi']",
#        "['Good for kids', 'Restaurant', 'Stadium seating']",
#        "['Bar onsite', 'Restaurant']"], dtype=object)

# %%
df_expanded_clean['Atmosphere'].astype(str).unique()
# Out:
# array([nan, "['Casual', 'Cozy']", "['Casual']",
#        "['Casual', 'Cozy', 'Quiet']", "['Cozy']",
#        "['Casual', 'Romantic']", "['Casual', 'Historic']",
#        "['Casual', 'Trending']", "['Trending']", "['Casual', 'Quiet']",
#        "['Cozy', 'Romantic']", "['Quiet', 'Romantic']", "['Romantic']",
#        "['Cozy', 'Historic']", "['Casual', 'Cozy', 'Romantic']",
#        "['Cozy', 'Romantic', 'Upscale']", "['Upscale']",
#        "['Romantic', 'Upscale']", "['Casual', 'Cozy', 'Upscale']",
#        "['Casual', 'Cozy', 'Historic']", "['Casual', 'Cosy']",
#        "['Cosy', 'Romantic', 'Upmarket']",
#        "['Cosy', 'Historic', 'Romantic', 'Upmarket']",
#        "['Casual', 'Cozy', 'Trending']",
#        "['Casual', 'Cozy', 'Romantic', 'Upscale']",
#        "['Casual', 'Cosy', 'Historic']", "['Romantic', 'Upmarket']",
#        "['Casual', 'Romantic', 'Trending', 'Upscale']",
#        "['Casual', 'Cosy', 'Upmarket']",
#        "['Cozy', 'Historic', 'Romantic', 'Upscale']",
#        "['Casual', 'Cozy', 'Historic', 'Romantic']",
#        "['Casual', 'Cosy', 'Romantic', 'Upmarket']",
#        "['Casual', 'Upmarket']",
#        "['Casual', 'Cozy', 'Historic', 'Romantic', 'Upscale']",
#        "['Cozy', 'Upscale']", "['Cozy', 'Historic', 'Romantic']",
#        "['Casual', 'Romantic', 'Upscale']", "['Casual', 'Upscale']",
#        "['Casual', 'Cozy', 'Historic', 'Trending']",
#        "['Casual', 'Cozy', 'Romantic', 'Trending']",
#        "['Historic', 'Romantic', 'Upscale']",
#        "['Casual', 'Historic', 'Romantic', 'Upscale']",
#        "['Casual', 'Cozy', 'Romantic', 'Trending', 'Upscale']",
#        "['Casual', 'Cozy', 'Trending', 'Upscale']",
#        "['Historic', 'Trending']",
#        "['Casual', 'Cozy', 'Historic', 'Upscale']",
#        "['Casual', 'Trending', 'Upscale']",
#        "['Casual', 'Cozy', 'Historic', 'Romantic', 'Trending', 'Upscale']",
#        "['Casual', 'Historic', 'Trending']",
#        "['Casual', 'Cozy', 'Historic', 'Romantic', 'Trending']"],
#       dtype=object)

# %%
df_expanded_clean['Crowd'].astype(str).unique()
# Out:
# array([nan, "['Groups', 'Tourists']", "['Family-friendly']",
#        "['College students', 'Family-friendly']", "['Groups', 'Locals']",
#        "['College students', 'Groups']", "['Groups']",
#        "['College students', 'Family-friendly', 'Tourists']",
#        "['Tourists']", "['Locals']", "['Family-friendly', 'Groups']",
#        "['Family-friendly', 'Tourists']", "['College students']",
#        "['Family-friendly', 'Groups', 'Tourists']",
#        "['Groups', 'Locals', 'Tourists']",
#        "['College students', 'Tourists']",
#        "['College students', 'Groups', 'Tourists']",
#        "['College students', 'Family-friendly', 'Groups']",
#        "['College students', 'Locals', 'Tourists']",
#        "['College students', 'Groups', 'Locals']",
#        "['Locals', 'Tourists']", "['College students', 'Locals']",
#        "['Groups', 'Tourists', 'University students']",
#        "['Family friendly', 'Tourists', 'University students']",
#        "['Family friendly', 'Groups', 'Tourists', 'University students']",
#        "['Family friendly', 'Groups', 'Tourists']",
#        "['Tourists', 'University students']",
#        "['Family friendly', 'Tourists']", "['Family friendly']",
#        "['College students', 'Family-friendly', 'Groups', 'Tourists']",
#        "['Groups', 'University students']",
#        "['Family friendly', 'University students']",
#        "['Family friendly', 'Groups', 'University students']",
#        "['Family friendly', 'Groups']", "['University students']",
#        "['Family-friendly', 'Groups', 'Locals', 'Tourists']"],
#       dtype=object)

# %%
columns_to_drop = ['state', 'address', 'hours', 'Service options', 'Accessibility', 'Offerings', 'Highlights', 'From the business', 'Health and safety', 'Health & safety', 'Planning', 'Payments', 'Amenities']
df_processed = df_expanded_clean.drop(columns=columns_to_drop)

# %%
df_processed.isna().sum()
# Out:
# user_id                0
# rating                 0
# text                   0
# gmap_id                0
# name_y                 0
# latitude               0
# longitude              0
# category               0
# avg_rating             0
# num_of_reviews         0
# price             118502
# Dining options    208545
# Popular for       220375
# Atmosphere        195120
# Crowd             204638
# dtype: int64

# %% [markdown]
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# Since our dataset is large enough, for the remaining missing values, we decided to just simple drop the rows with missing `Popular for`, `Dining options`, and `price`.

# %%
df_processed2 = df_processed.dropna(subset=['Popular for', 'Dining options', 'price'])
df_processed2.isna().sum()
# Out:
# user_id               0
# rating                0
# text                  0
# gmap_id               0
# name_y                0
# latitude              0
# longitude             0
# category              0
# avg_rating            0
# num_of_reviews        0
# price                 0
# Dining options        0
# Popular for           0
# Atmosphere          370
# Crowd             22562
# dtype: int64

# %% [markdown]
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# We can encode the missing values in `Atmosphere` as 'unknown', and the ones in `Crowd` as 'any'.
#
# We will also need to process the representating of `price`. We decided to encode the `$` symbols as numbers, so `$` = 1, `$$` = 2, an so on.

# %%
# Replace NA values in 'Atmosphere' column with 'unknown'
df_processed2.loc[:, 'Atmosphere'] = df_processed2['Atmosphere'].fillna('unknown')

# Replace NA values in 'Crowd' column with 'any'
df_processed2.loc[:, 'Crowd'] = df_processed2['Crowd'].fillna('any')

# %%
df_processed2.isna().sum()
# Out:
# user_id           0
# rating            0
# text              0
# gmap_id           0
# name_y            0
# latitude          0
# longitude         0
# category          0
# avg_rating        0
# num_of_reviews    0
# price             0
# Dining options    0
# Popular for       0
# Atmosphere        0
# Crowd             0
# dtype: int64

# %%
def encode_price(price):
    if pd.isna(price):
        return None  # Use np.nan 
    price = price.replace('₩', '$')  # Normalize '₩' to '$'
    return len(price)  # The number of '$' symbols corresponds to the price level

# %%
df_processed2.loc[:, 'price'] = df_processed2['price'].apply(encode_price)

# %%
df_processed2.head()
# Out:
#           user_id  rating                                               text  \
# 20   1.091166e+20     3.0                                       It's alright
# 22   1.103553e+20     3.0                              it was hard and yucky
# 142  1.172942e+20     5.0  Had a small lunch here and didn't have one pro...
# 144  1.035610e+20     5.0              small place with Good food and price.
# 146  1.033256e+20     5.0      I love their pupusas. They are now la parilla
#
#                                    gmap_id            name_y   latitude  \
# 20   0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza  42.559072
# 22   0x89e3169821e62d4d:0x14ff0683c1ebca0e  Three Star Pizza  42.559072
# 142  0x89e37bae6173982b:0x2b2156422703d5cb   Mi Casa Tu Casa  42.308251
# 144  0x89e37bae6173982b:0x2b2156422703d5cb   Mi Casa Tu Casa  42.308251
# 146  0x89e37bae6173982b:0x2b2156422703d5cb   Mi Casa Tu Casa  42.308251
#
#      longitude                                           category  avg_rating  \
# 20  -70.881542  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 22  -70.881542  [Pizza restaurant, Italian restaurant, Deliver...         3.9
# 142 -71.058650  [Latin American restaurant, Guatemalan restaur...         4.5
# 144 -71.058650  [Latin American restaurant, Guatemalan restaur...         4.5
# 146 -71.058650  [Latin American restaurant, Guatemalan restaur...         4.5
#
#      num_of_reviews price                       Dining options  \
# 20             48.0     2  [Breakfast, Lunch, Dinner, Dessert]
# 22             48.0     2  [Breakfast, Lunch, Dinner, Dessert]
# 142            28.0     1    [Lunch, Dinner, Dessert, Seating]
# 144            28.0     1    [Lunch, Dinner, Dessert, Seating]
# 146            28.0     1    [Lunch, Dinner, Dessert, Seating]
#
#                                  Popular for      Atmosphere  \
# 20   [Breakfast, Lunch, Dinner, Solo dining]  [Casual, Cozy]
# 22   [Breakfast, Lunch, Dinner, Solo dining]  [Casual, Cozy]
# 142             [Lunch, Dinner, Solo dining]        [Casual]
# 144             [Lunch, Dinner, Solo dining]        [Casual]
# 146             [Lunch, Dinner, Solo dining]        [Casual]
#
#                                    Crowd
# 20                                   any
# 22                                   any
# 142  [Family-friendly, Groups, Tourists]
# 144  [Family-friendly, Groups, Tourists]
# 146  [Family-friendly, Groups, Tourists]

# %%
df_processed2.to_csv('data/cleaned_data.csv')

# %%
df_final = pd.read_csv('data/cleaned_data.csv')

# %% [markdown]
# # 2. EDA

# %%
df = df_final

# %% [markdown]
# ## Exploring the distribution of ratings
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# * Ratings are on a 1 to 5 scale.
# * The majority of reviews are positive, with over 700k reviews with a rating of 4 or 5. There is also a slight spike in the number of 1 star reviews than 2 star reviews, suggesting that users who view a restaurant badly are more likely to rate the most extreme rating of 1 star.

# %%
# Distribution of ratings: To understand the overall sentiment towards the businesses.

plt.hist(df['rating'], bins = 5, edgecolor = 'black')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
# show exact counts
for i in range(1, 6):
    plt.text(i + 0.5 if i == 1 else i + 0.3 if i == 2 else i + 0.1 if i == 3 else i if i == 4 else i - 0.2, len(df[df['rating'] == i]), str(len(df[df['rating'] == i])), ha='right', va='bottom')
# change x ticks to read 1, 2, 3, 4, 5
plt.xticks(np.arange(1, 6, 1))

plt.show()

# %% [markdown]
# ## Exploring review counts per local business
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# * Most restaurants have 0-100 reviews.
# * The mean number of reviews is around 100, and the standard deviation is also around 100.
# * A small number of businesses might be overrepresented in our dataset, especially the few outliers with over 600 reviews.

# %%
# Count of reviews per business - To see which businesses have been reviewed the most.

# describe the count of reviews per business
print("Summary statistics for count of reviews per business:")
print(df['gmap_id'].value_counts().describe())

df['gmap_id'].value_counts().plot(kind='hist', bins=100, edgecolor='black')
plt.title('Count of Reviews per Business')
plt.xlabel('Number of Reviews')
plt.ylabel('Count of Businesses')
plt.show()
# Out:
# Summary statistics for count of reviews per business:
# count    9657.000000
# mean       98.474682
# std       103.101616
# min         1.000000
# 25%        32.000000
# 50%        66.000000
# 75%       128.000000
# max      1319.000000
# Name: count, dtype: float64

# %% [markdown]
# ## Exploring review lengths (in terms of number of characters)
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# * We see that review lengths are distributed similarly to business ratings, with a large number of reviews having a smaller number of characters, and with the number of reviews decreasing at a decreasing rate as the review length increases.
# * The mean review length is around 115, but with a large standard deviation of around 168.
# * We also see outliers, especially the review with 8973 characters.

# %%
# Review length analysis: To see the distribution of the length of the review texts.

df['review_length'] = df['text'].apply(lambda x: len(x) if x and isinstance(x, str) else 0)

# describe the review length
print("Summary statistics for review length:")
print(df['review_length'].describe())

plt.hist(df['review_length'], bins=100, edgecolor='black')
plt.title('Distribution of Review Length')
plt.xlabel('Review Length')
plt.ylabel('Count')
plt.show()
# Out:
# Summary statistics for review length:
# count    950970.000000
# mean        114.726520
# std         168.111991
# min           0.000000
# 25%          29.000000
# 50%          60.000000
# 75%         132.000000
# max        8973.000000
# Name: review_length, dtype: float64

# %% [markdown]
# ## Exploring correlation between review length and rating
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# * We analyzed the correlation between the length of the review text and the rating. The correlation coefficient is around -0.189, which suggests that there is only a weak negative correlation between the length of the review and the rating.
# * This result is consistent with our intuition, as the length of a review does not necessarily indicate its quality or sentiment.
# * However, perhaps some angrier customers might leave longer reviews, which could explain the slight negative correlation.

# %%
# Correlation between review length and rating: To see if there is a correlation between the length of the review and the rating given.

# plot the correlation between review length and rating
sns.scatterplot(x='rating', y='review_length', data=df)
plt.title('Correlation between Review Length and Rating')
plt.xlabel('Rating')
plt.ylabel('Review Length')
plt.xticks(np.arange(1, 6, 1))
plt.show()

correlation_matrix = df[['rating', 'review_length']].corr()
print("Correlation matrix:")
print(correlation_matrix)
# Out:
# Correlation matrix:
#                  rating  review_length
# rating         1.000000      -0.189299
# review_length -0.189299       1.000000

# %% [markdown]
# ## Number of unique authors
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# * We see that we have 155583 unique authors for our 950,970 reviews, suggesting that most authors leave more than one review.
# * This is confirmed by the mean number of reviews per author, which is around 6.1 with a standard deviation of 7.6.
# * The shape of the distribution is once again similar to the previous two, with the number of authors decreasing at a decreasing rate as the number of reviews per author increases.

# %%
# total reviews
total_reviews = len(df)
total_reviews
# Out:
# 950970

# %%
# How many unique authors?

print("Number of unique authors: ", df['user_id'].nunique())

# describe the count of ratings per author
print("Summary statistics for number of ratings per author:")
print(df['user_id'].value_counts().describe())

df['user_id'].value_counts().plot(kind='hist', bins=100, edgecolor='black')
plt.title('Count of Ratings per Author')
plt.xlabel('Number of Ratings')
plt.ylabel('Count of Authors')
plt.show()
# Out:
# Number of unique authors:  155583
# Summary statistics for number of ratings per author:
# count    155583.000000
# mean          6.112300
# std           7.601384
# min           1.000000
# 25%           2.000000
# 50%           4.000000
# 75%           7.000000
# max         257.000000
# Name: count, dtype: float64

# %% [markdown]
# ## Simple sentiment analysis - Baseline Model
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# * We used the `TextBlob` library to perform a simple sentiment analysis on the review text.
# * First, we dropped reviews with no text, as they would not provide any information for sentiment analysis.
# * We then calculated the polarity of each review, which ranges from -1 (most negative) to 1 (most positive).
# * Plotting a histogram and summary statistics, we see that most reviews are moderately positive with a mean polarity of 0.42 and a standard deviation of 0.36. This is consistent with our earlier observation that most ratings are positive (5 stars).
# * The distribution is roughly bell-shaped, but with a density spike at 0 and a few more spikes above 0.5.

# %%
# Simple sentiment analysis on review text

# Add a column to the dataframe with the sentiment of the review
df_dropped = df.dropna(subset=['text'])
df_dropped['sentiment'] = df_dropped['text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# print summary statistics
print("Summary statistics for sentiment:")
print(df_dropped['sentiment'].describe())

# plot the distribution of sentiment
plt.hist(df_dropped['sentiment'], bins=100, edgecolor='black')
plt.title('Distribution of Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
# Summary statistics for sentiment:
# count    950960.000000
# mean          0.419850
# std           0.356284
# min          -1.000000
# 25%           0.197222
# 50%           0.450000
# 75%           0.700000
# max           1.000000
# Name: sentiment, dtype: float64
# /var/folders/d8/kwvs0tzd5t7dkrqj0r00cjzr0000gn/T/ipykernel_21468/3980335880.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dropped['sentiment'] = df_dropped['text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# There is a moderate positive correlation between sentiment score and rating, with a correlation coefficient of 0.54. This suggests that reviews with higher ratings tend to have more positive sentiment scores, which is expected. This is a good result for our training data.
#
# We were worried that meaningful sentiment might not be extracted from short reviews, but the correlation suggests that the sentiment analysis is capturing the sentiment of the reviews decently well. Yay!

# %%
# Find correlation between sentiment and rating
correlation_matrix = df_dropped[['rating', 'sentiment']].corr()
print("Correlation matrix:")
print(correlation_matrix)
# Out:
# Correlation matrix:
#             rating  sentiment
# rating     1.00000    0.54039
# sentiment  0.54039    1.00000

# %% [markdown]
# ## Summary of findings
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# * We see that the majority of ratings given by Google users are 5 out of 5. This aligns with the Google text review sentiment analysis, which found that the majority of the reviews had a postive sentiment.
# * We also found that there is a weak correlation between the length of a text review and the rating given by the same Google user. However, it could be helpful to note that based on the visualization displayed above, the review length was longest for either 1 or 5 star reviews.
# * In the sentiment analysis, we found that majority of the text reviews result in a sentiment score near 0, which suggests that many reviews are neutral. The second most common sentiment scores are those near 1, which suggests that there are also many (but not as many) reviews that are highly positive.
# * This summarizes the distributional features of our reviews in their length, sentiment and the related score.

# %% [markdown]
# ## Revised Project Question
#
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# Creating a restaurant recommendation system based on textual reviews and and user-inputted prompts.

# %% [markdown]
# ## Implementation Plan -- Draft Pipeline

# %% [markdown]
# <div style="background-color:#3F7FBF; color:white; padding:10px">
#
# The structure of our problem is similar to that of designing a recommender system. We describe an initial approach that comes to mind:
#
# **Recommender Model Pipeline:**
# - **Training step** (preprocessing): Embed the reviews for all restaurants as vectors using sentence embeddings (BERT), or a combined approach using BERT and other feature engineered features from the restaurant information that we have. One approach is then to cluster restaurants in an unsupervised way in the feature space using an approach like KNN or t-SNE. Perhaps we can do this in an informed way, however.
# - **Interaction step:** Then, we may take a user prompt of sentence length describing the restaurant type they are looking for, and use the fine-tuned BERT pipeline to get a vector representation of the prompt.
# - **Matching step:** Then we can take the top recommendations as the closest three or so restaurants in the feature space to the prompt. We can incorporate additional heuristics in this matching step.
#
#
# **Potential Issues:**
# - Reviews and prompts are semantically different. We might encounter unexpected relationships between the restaurants closest in the feature space based on reviews and the inputted prompts.
# - Perhaps a content-based filtering approach is more directly applicable as a pipeline (ref: https://developers.google.com/machine-learning/recommendation/content-based/basics).
# - With an unsupervised approach like this, we have no systematized way to measure whether our recommending algorithm is doing a good job at matching prompts to restaurants. But this is the nature of trying a recommendation system rather than a predictive model. We do not have the resources to conduct proper A/B testing, which would otherwise be a canonical solution.
# -  A collaborative filtering approach would be great, but is infeasible since we cannot recruit enough users.
